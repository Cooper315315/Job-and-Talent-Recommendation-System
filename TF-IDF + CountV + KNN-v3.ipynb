# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# !pip install pdfplumber -q
# !apt-get install ocrmypdf -q   #installing OCR library

# %%
# import pdfplumber
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict
import pandas as pd 
from nltk.collocations import *
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')

# %%
# with pdfplumber.open("/content/drive/MyDrive/test.pdf") as pdf:
#     text=""
#     pages = pdf.pages
#     for page in pages:
#         text += page.extract_text(x_tolerance=2)
#         print(text)

# %% [markdown]
# # Import CV and scraped data

# %%
# Import CV
f=open('test.txt','r', errors = 'ignore')
text=f.read()

# Locations
f1=open('hk_districts.txt','r', errors = 'ignore')
text1=f1.read()
locations = word_tokenize(text1.replace("\n", " "))

# Additional stopwords
f2=open('stopwords.txt','r', errors = 'ignore')
text2=f2.read()
stopwords_additional = word_tokenize(text2.replace("\n", " "))

# %%
def nlp(x):
    word_sent = word_tokenize(x.lower().replace("\n",""))
    _stopwords = set(stopwords.words('english') + list(punctuation)+list("●")+list('–')+list('’')+locations+stopwords_additional)
    word_sent=[word for word in word_sent if word not in _stopwords]
    lemmatizer = WordNetLemmatizer()
    NLP_Processed_CV = [lemmatizer.lemmatize(word) for word in word_tokenize(" ".join(word_sent))]
#     return " ".join(NLP_Processed_CV)
    return NLP_Processed_CV

# %%
def get_key_word(x):
    finder = BigramCollocationFinder.from_words(x)
    lst = []
    Key_word_from_CV = []
    for i in sorted(finder.ngram_fd.items()):
    # if a double word appears more than once, then print it out.
        if i[1] > 1:
            print(i)
            lst.append(i[0])
        else:
            pass

    # print("************************")
    for j in lst:
    #     print(" ".join(j))
        Key_word_from_CV.append(" ".join(j))
    return Key_word_from_CV

# %%
NLP_Processed_CV = nlp(text)
# NLP_Processed_CV=' '.join(NLP_Processed_CV)
NLP_Processed_CV
# Out:
# ['summarymotivated',
#  'determined',
#  'individual',
#  'data',
#  'science',
#  'machine',
#  'learning',
#  'bootcamp',
#  'experienced',
#  'python',
#  'data',
#  'analysis',
#  'machine',
#  'learning',
#  'multiple',
#  'data',
#  'science',
#  'project',
#  'background',
#  'engineering',
#  'enables',
#  'develop',
#  'logical',
#  'analytical',
#  'skill',
#  'well',
#  'recognizing',
#  'teamwork',
#  'effective',
#  'communication',
#  'currently',
#  'seeking',
#  'opportunity',
#  'deploy',
#  'data',
#  'analytic',
#  'skills.technical',
#  'skill',
#  'proficient',
#  'python',
#  'panda',
#  'keras-tensorflow',
#  'machine',
#  'learning',
#  'deep',
#  'learning',
#  'tableau',
#  'familiar',
#  'sqlxccelerate',
#  'full-time',
#  'data',
#  'science',
#  'machine',
#  'learning',
#  'immersive',
#  'bootcamp',
#  '03/2021',
#  '07',
#  '2021',
#  'graduate',
#  'xccelerate',
#  'full-time',
#  'data',
#  'science',
#  'bootcamp',
#  'developing',
#  'data',
#  'science/',
#  'machine',
#  'learning',
#  'project',
#  'individually',
#  'team',
#  'project',
#  'house',
#  'ownership',
#  'scheme',
#  'market',
#  'analysis',
#  'web-scraping',
#  'panda',
#  'deployed',
#  'web-scraping',
#  'technique',
#  'website',
#  'valuable',
#  'dataset',
#  'analysis',
#  'deployed',
#  'panda',
#  'visualization',
#  'tool',
#  'analyze',
#  'housing',
#  'estate',
#  'identified',
#  'insight',
#  'public',
#  'housing',
#  'estate',
#  'market',
#  'i.e',
#  'location',
#  'pricing.flight',
#  'ticket',
#  'price',
#  'prediction',
#  'machine',
#  'learning',
#  'panda',
#  'performed',
#  'technique',
#  'panda',
#  'regular',
#  'expression',
#  'large',
#  'dataset',
#  'data',
#  'preprocessing',
#  'phase',
#  'trained',
#  'deployed',
#  'regression',
#  'model',
#  'conduct',
#  'price',
#  'prediction',
#  'model',
#  'predict',
#  'price',
#  '75',
#  'facial',
#  'detection',
#  'recognition',
#  'system',
#  'deep',
#  'learning',
#  'deployed',
#  'facial',
#  'detection',
#  'technique',
#  'captured',
#  'face',
#  'real-life',
#  'picture',
#  'developed',
#  'optimized',
#  'model',
#  'convolution',
#  'neural',
#  'network',
#  'cnn',
#  'image',
#  'prediction',
#  'model',
#  'achieved',
#  '85',
#  'gender',
#  'prediction',
#  '83',
#  'emotion',
#  'prediction.work',
#  'experience',
#  'laboratory',
#  'technician',
#  'smith',
#  'associate',
#  'east',
#  '07/',
#  '2017',
#  '06/',
#  '2020conduct',
#  'quality',
#  'control',
#  'electronic',
#  'component',
#  'visual',
#  'inspection',
#  'testingdetect',
#  'counterfeit',
#  'electronic',
#  'component',
#  'report',
#  'relevant',
#  'discrepancy',
#  'technician',
#  'crestron',
#  'asia',
#  'limited',
#  '11/',
#  '2015',
#  '02/',
#  '2017perform',
#  'testing',
#  'repairing',
#  'company',
#  "'s",
#  'product',
#  'education',
#  'bachelor',
#  'engineering',
#  'chemical',
#  'engineering',
#  'university',
#  'birmingham',
#  '09/2012',
#  '06/2015',
#  'brockenhurst',
#  'college',
#  'a-levels',
#  'mathematics',
#  'chemistry',
#  'physic',
#  'chinese',
#  '09/2010',
#  '06',
#  '2012',
#  'language',
#  'native',
#  'cantonese',
#  'fluent',
#  'english',
#  'familiar',
#  'mandarin']

# %%
key_word = get_key_word(NLP_Processed_CV)
key_word
# Out:
# (('data', 'science'), 4)
# (('deep', 'learning'), 2)
# (('electronic', 'component'), 2)
# (('facial', 'detection'), 2)
# (('full-time', 'data'), 2)
# (('housing', 'estate'), 2)
# (('machine', 'learning'), 6)
# (('prediction', 'model'), 2)
# (('price', 'prediction'), 2)
# (('science', 'machine'), 2)
# ['data science',
#  'deep learning',
#  'electronic component',
#  'facial detection',
#  'full-time data',
#  'housing estate',
#  'machine learning',
#  'prediction model',
#  'price prediction',
#  'science machine']

# %%
# print(NLP_Processed_CV)
# print(key_word)
df.shape
# Out:
# (20137, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20137 entries, 0 to 20136
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20137 non-null  int64
#  1   JobID             20137 non-null  int64
#  2   title             20136 non-null  object
#  3   company           20137 non-null  object
#  4   location          15971 non-null  object
#  5   salary            20137 non-null  object
#  6   post_date         20137 non-null  object
#  7   job highlights    20068 non-null  object
#  8   job description   20137 non-null  object
#  9   company overview  16740 non-null  object
#  10  career level      20137 non-null  object
#  11  qualification     14122 non-null  object
#  12  experience        11576 non-null  object
#  13  job type          20137 non-null  object
#  14  industry          20137 non-null  object
#  15  benefit           12913 non-null  object
#  16  webpage           20137 non-null  object
#  17  sal_low           20137 non-null  int64
#  18  sal_high          20137 non-null  int64
#  19  All               20137 non-null  object
# dtypes: int64(4), object(16)
# memory usage: 3.1+ MB

# %%
#Import scraped data
df = pd.read_csv("whole-v7-nlp.csv")
df.head(2)
# Out:
#    Unnamed: 0  JobID                   title  \
# 0           0      0    Assistant IT Manager
# 1           1      1  Finance and IT Manager
#
#                                company     location salary  \
# 0                        Wang On Group  Kowloon Bay      0
# 1  Abdoolally Ebrahim Services Limited    Kwun Tong      0
#
#             post_date                                     job highlights  \
# 0  Posted 2 hours ago  Responsible for stability performance security...
# 1  Posted 3 hours ago  Responsible for the finance and IT operations,...
#
#                                      job description  \
# 0  Responsibilities:Analyze business requirements...
# 1  ResponsibilitiesFinanceResponsible for the fin...
#
#                                     company overview career level  \
# 0  \nWang On Group\n\nWang On Group (Stock Code: ...       Middle
# 1  Abdoolally Ebrahim Group started its business ...       Senior
#
#   qualification experience              job type  \
# 0        Degree    8 years  Full Time, Permanent
# 1        Degree    5 years  Full Time, Permanent
#
#                          industry  \
# 0  Management Consultancy/Service
# 1        Trading and Distribution
#
#                                              benefit  \
# 0  Education allowance, Free shuttle bus, Life in...
# 1  Double pay, Education allowance, Medical insur...
#
#                                              webpage  sal_low  sal_high  \
# 0  https://hk.jobsdb.com/hk/en/job/assistant-it-m...        0         0
# 1  https://hk.jobsdb.com/hk/en/job/finance-and-it...        0         0
#
#                                                  All
# 0  ['assistant manager wang group responsible sta...
# 1  ['finance manager abdoolally ebrahim service l...

# %%
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import TfidfVectorizer
# tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidf_jobid = tfidf_vectorizer.fit_transform(df['All'])
# # print(tfidf_jobid)
# user_tfidf = tfidf_vectorizer.transform(df2['All'])

# %%
# cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)
# output2 = list(cos_similarity_tfidf)
# output2

# %%
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import TfidfVectorizer
# def TFIDF(scraped_data, cv):
#     tfidf_vectorizer = TfidfVectorizer(stop_words='english')

#     # TF-IDF Scraped data
#     tfidf_jobid = tfidf_vectorizer.fit_transform(scraped_data)

#     # TF-IDF CV
#     user_tfidf = tfidf_vectorizer.transform(cv)

#     # Using cosine_similarity on (Scraped data) & (CV)
#     cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)

#     output2 = list(cos_similarity_tfidf)
#     return output2
    
# output2 = TFIDF(df['All'], df2['All'])
# output2

# %% [markdown]
# # Put keyword/CV into a dataframe

# %%
df2 = pd.DataFrame()
# append columns to an empty DataFrame
df2['title'] = ["I"]
df2['job highlights'] = ["I"]
df2['job description'] = ["I"]
df2['company overview'] = ["I"]
df2['industry'] = ["I"]

# Compare with the key words from CV only
df2['All'] = " ".join(key_word)

# Compare with the entire CV
# df2['All'] = " ".join(NLP_Processed_CV)
# df2

# %% [markdown]
# # Create get_recommendation function

# %%
def get_recommendation(top, df_all, scores):
    recommendation = pd.DataFrame(columns = ['JobID',  'title', 'industry', 'job description','score'])
    count = 0
    for i in top:
#         recommendation.at[count, 'ApplicantID'] = u
        recommendation.at[count, 'JobID'] = df.index[i]
        recommendation.at[count, 'title'] = df['title'][i]
        recommendation.at[count, 'industry'] = df['industry'][i]
#         recommendation.at[count, 'location'] = df['location'][i]
        recommendation.at[count, 'job description'] = df['job description'][i]
        recommendation.at[count, 'score'] =  scores[count]
        count += 1
    return recommendation

# %% [markdown]
# # TFIDF

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer


def TFIDF(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    # TF-IDF Scraped data
    tfidf_jobid = tfidf_vectorizer.fit_transform(scraped_data)

    # TF-IDF CV
    user_tfidf = tfidf_vectorizer.transform(cv)

    # Using cosine_similarity on (Scraped data) & (CV)
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf,x),tfidf_jobid)

    output2 = list(cos_similarity_tfidf)
    return output2
    
output2 = TFIDF(df['All'], df2['All'])
output2
# Out:
# [array([[0.01004203]]),
#  array([[0.00277372]]),
#  array([[0.01380723]]),
#  array([[0.0042945]]),
#  array([[0.01483838]]),
#  array([[0.00927136]]),
#  array([[0.]]),
#  array([[0.0074321]]),
#  array([[0.02078868]]),
#  array([[0.00356108]]),
#  array([[0.00450561]]),
#  array([[0.00479991]]),
#  array([[0.00466231]]),
#  array([[0.]]),
#  array([[0.00863563]]),
#  array([[0.00862199]]),
#  array([[0.00314284]]),
#  array([[0.00507078]]),
#  array([[0.01038314]]),
#  array([[0.02121474]]),
#  array([[0.01357133]]),
#  array([[0.00945792]]),
#  array([[0.02001338]]),
#  array([[0.0120537]]),
#  array([[0.02072318]]),
#  array([[0.]]),
#  array([[0.02679346]]),
#  array([[0.00785341]]),
#  array([[0.01091518]]),
#  array([[0.01496459]]),
#  array([[0.02635305]]),
#  array([[0.00349383]]),
#  array([[0.03310537]]),
#  array([[0.01452733]]),
#  array([[0.02757567]]),
#  array([[0.00277911]]),
#  array([[0.00247154]]),
#  array([[0.]]),
#  array([[0.00420295]]),
#  array([[0.02411737]]),
#  array([[0.02654077]]),
#  array([[0.00298215]]),
#  array([[0.01891538]]),
#  array([[0.010925]]),
#  array([[0.00334782]]),
#  array([[0.]]),
#  array([[0.01618232]]),
#  array([[0.02532373]]),
#  array([[0.0508424]]),
#  array([[0.0086545]]),
#  array([[0.00250267]]),
#  array([[0.01680954]]),
#  array([[0.03695219]]),
#  array([[0.00710077]]),
#  array([[0.01043145]]),
#  array([[0.00653347]]),
#  array([[0.00838437]]),
#  array([[0.01583208]]),
#  array([[0.00657226]]),
#  array([[0.]]),
#  array([[0.01843551]]),
#  array([[0.00419282]]),
#  array([[0.00959632]]),
#  array([[0.00538995]]),
#  array([[0.00538734]]),
#  array([[0.00762752]]),
#  array([[0.04014218]]),
#  array([[0.00974598]]),
#  array([[0.00539912]]),
#  array([[0.0087458]]),
#  array([[0.00212683]]),
#  array([[0.01313821]]),
#  array([[0.01133193]]),
#  array([[0.01449289]]),
#  array([[0.03489239]]),
#  array([[0.0146008]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.00383162]]),
#  array([[0.03613514]]),
#  array([[0.017711]]),
#  array([[0.00495831]]),
#  array([[0.03391307]]),
#  array([[0.0128174]]),
#  array([[0.01188193]]),
#  array([[0.01021129]]),
#  array([[0.01080117]]),
#  array([[0.00889914]]),
#  array([[0.0466023]]),
#  array([[0.01168134]]),
#  array([[0.01893129]]),
#  array([[0.0156956]]),
#  array([[0.00873328]]),
#  array([[0.0188954]]),
#  array([[0.01799381]]),
#  array([[0.01708589]]),
#  array([[0.00469231]]),
#  array([[0.00378184]]),
#  array([[0.01198674]]),
#  array([[0.00866029]]),
#  array([[0.]]),
#  array([[0.01692412]]),
#  array([[0.01704755]]),
#  array([[0.01046205]]),
#  array([[0.02726479]]),
#  array([[0.01363564]]),
#  array([[0.01271232]]),
#  array([[0.01307116]]),
#  array([[0.]]),
#  array([[0.00343228]]),
#  array([[0.02740348]]),
#  array([[0.01542139]]),
#  array([[0.00601767]]),
#  array([[0.01888705]]),
#  array([[0.00974984]]),
#  array([[0.]]),
#  array([[0.00640296]]),
#  array([[0.00465033]]),
#  array([[0.00699779]]),
#  array([[0.01520236]]),
#  array([[0.00947863]]),
#  array([[0.]]),
#  array([[0.01451825]]),
#  array([[0.00442499]]),
#  array([[0.01786728]]),
#  array([[0.01978689]]),
#  array([[0.00969868]]),
#  array([[0.00775688]]),
#  array([[0.01222287]]),
#  array([[0.00958692]]),
#  array([[0.00894836]]),
#  array([[0.00344391]]),
#  array([[0.02794731]]),
#  array([[0.02196575]]),
#  array([[0.01281665]]),
#  array([[0.00580238]]),
#  array([[0.01016578]]),
#  array([[0.00546539]]),
#  array([[0.0085419]]),
#  array([[0.00777596]]),
#  array([[0.01460443]]),
#  array([[0.00265744]]),
#  array([[0.00925336]]),
#  array([[0.02013403]]),
#  array([[0.02270872]]),
#  array([[0.01411827]]),
#  array([[0.00760277]]),
#  array([[0.03800069]]),
#  array([[0.01180719]]),
#  array([[0.02825179]]),
#  array([[0.]]),
#  array([[0.00581708]]),
#  array([[0.01219256]]),
#  array([[0.00859087]]),
#  array([[0.00710937]]),
#  array([[0.01111092]]),
#  array([[0.01177545]]),
#  array([[0.]]),
#  array([[0.01887282]]),
#  array([[0.02253835]]),
#  array([[0.01410425]]),
#  array([[0.01974406]]),
#  array([[0.0042392]]),
#  array([[0.03491048]]),
#  array([[0.00860115]]),
#  array([[0.01037503]]),
#  array([[0.00673259]]),
#  array([[0.00347267]]),
#  array([[0.03336051]]),
#  array([[0.01440714]]),
#  array([[0.00776345]]),
#  array([[0.02460694]]),
#  array([[0.02257286]]),
#  array([[0.01040871]]),
#  array([[0.00704018]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.02293753]]),
#  array([[0.01022602]]),
#  array([[0.00564302]]),
#  array([[0.00133994]]),
#  array([[0.01418598]]),
#  array([[0.]]),
#  array([[0.023356]]),
#  array([[0.00376827]]),
#  array([[0.01069021]]),
#  array([[0.01030249]]),
#  array([[0.00269086]]),
#  array([[0.02227531]]),
#  array([[0.00790244]]),
#  array([[0.01240589]]),
#  array([[0.00714531]]),
#  array([[0.00564294]]),
#  array([[0.01048457]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01966339]]),
#  array([[0.04542732]]),
#  array([[0.00913604]]),
#  array([[0.01658411]]),
#  array([[0.06106576]]),
#  array([[0.0106978]]),
#  array([[0.01904032]]),
#  array([[0.00904974]]),
#  array([[0.01157288]]),
#  array([[0.05711304]]),
#  array([[0.00711158]]),
#  array([[0.07459946]]),
#  array([[0.00342501]]),
#  array([[0.00245743]]),
#  array([[0.00404367]]),
#  array([[0.01366566]]),
#  array([[0.]]),
#  array([[0.00689571]]),
#  array([[0.]]),
#  array([[0.03002113]]),
#  array([[0.01442719]]),
#  array([[0.13767659]]),
#  array([[0.00584665]]),
#  array([[0.01053376]]),
#  array([[0.00281196]]),
#  array([[0.01370496]]),
#  array([[0.02364354]]),
#  array([[0.05013914]]),
#  array([[0.01131251]]),
#  array([[0.02159959]]),
#  array([[0.02121312]]),
#  array([[0.03547084]]),
#  array([[0.01622332]]),
#  array([[0.01497735]]),
#  array([[0.00652847]]),
#  array([[0.01677068]]),
#  array([[0.0056641]]),
#  array([[0.01035793]]),
#  array([[0.00697328]]),
#  array([[0.00418036]]),
#  array([[0.00614991]]),
#  array([[0.01241466]]),
#  array([[0.01364415]]),
#  array([[0.]]),
#  array([[0.07297617]]),
#  array([[0.01605754]]),
#  array([[0.00701911]]),
#  array([[0.01335222]]),
#  array([[0.00332331]]),
#  array([[0.00633831]]),
#  array([[0.00969808]]),
#  array([[0.01151731]]),
#  array([[0.]]),
#  array([[0.00566413]]),
#  array([[0.00747208]]),
#  array([[0.00445709]]),
#  array([[0.01452965]]),
#  array([[0.01505122]]),
#  array([[0.09029814]]),
#  array([[0.00335085]]),
#  array([[0.00630973]]),
#  array([[0.00316318]]),
#  array([[0.01111801]]),
#  array([[0.00680879]]),
#  array([[0.01481334]]),
#  array([[0.01624657]]),
#  array([[0.06877987]]),
#  array([[0.00822871]]),
#  array([[0.02317292]]),
#  array([[0.00918876]]),
#  array([[0.02049893]]),
#  array([[0.00630588]]),
#  array([[0.01496381]]),
#  array([[0.00339856]]),
#  array([[0.02516623]]),
#  array([[0.01718899]]),
#  array([[0.07089025]]),
#  array([[0.00435838]]),
#  array([[0.02625635]]),
#  array([[0.0157423]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01858669]]),
#  array([[0.00495136]]),
#  array([[0.01265362]]),
#  array([[0.]]),
#  array([[0.00837281]]),
#  array([[0.10521825]]),
#  array([[0.01212709]]),
#  array([[0.00405438]]),
#  array([[0.00901272]]),
#  array([[0.03353136]]),
#  array([[0.04527893]]),
#  array([[0.02736102]]),
#  array([[0.11717289]]),
#  array([[0.00514793]]),
#  array([[0.01641024]]),
#  array([[0.0146419]]),
#  array([[0.01255172]]),
#  array([[0.]]),
#  array([[0.14801724]]),
#  array([[0.00680997]]),
#  array([[0.00884542]]),
#  array([[0.00906868]]),
#  array([[0.00580206]]),
#  array([[0.01629307]]),
#  array([[0.]]),
#  array([[0.0025204]]),
#  array([[0.00318254]]),
#  array([[0.02003677]]),
#  array([[0.0046206]]),
#  array([[0.0083328]]),
#  array([[0.]]),
#  array([[0.01006711]]),
#  array([[0.01560106]]),
#  array([[0.01110982]]),
#  array([[0.01862503]]),
#  array([[0.00951072]]),
#  array([[0.]]),
#  array([[0.00331396]]),
#  array([[0.00802306]]),
#  array([[0.]]),
#  array([[0.00288959]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01384512]]),
#  array([[0.01930882]]),
#  array([[0.00880789]]),
#  array([[0.]]),
#  array([[0.00403961]]),
#  array([[0.01325336]]),
#  array([[0.]]),
#  array([[0.08462976]]),
#  array([[0.0142039]]),
#  array([[0.00493152]]),
#  array([[0.00593884]]),
#  array([[0.00719725]]),
#  array([[0.01976133]]),
#  array([[0.02283159]]),
#  array([[0.05185644]]),
#  array([[0.01250366]]),
#  array([[0.00892993]]),
#  array([[0.02339468]]),
#  array([[0.01861674]]),
#  array([[0.03352986]]),
#  array([[0.00942432]]),
#  array([[0.01007255]]),
#  array([[0.0325949]]),
#  array([[0.01734857]]),
#  array([[0.0066415]]),
#  array([[0.00635592]]),
#  array([[0.00732918]]),
#  array([[0.02381224]]),
#  array([[0.00740778]]),
#  array([[0.13422052]]),
#  array([[0.00926057]]),
#  array([[0.01856218]]),
#  array([[0.02355611]]),
#  array([[0.00901729]]),
#  array([[0.]]),
#  array([[0.03408623]]),
#  array([[0.0152691]]),
#  array([[0.00860524]]),
#  array([[0.02864291]]),
#  array([[0.01683152]]),
#  array([[0.01763863]]),
#  array([[0.02156146]]),
#  array([[0.]]),
#  array([[0.01547061]]),
#  array([[0.03104752]]),
#  array([[0.02247698]]),
#  array([[0.01600858]]),
#  array([[0.01524039]]),
#  array([[0.02827062]]),
#  array([[0.00686293]]),
#  array([[0.00600243]]),
#  array([[0.]]),
#  array([[0.01208684]]),
#  array([[0.0109095]]),
#  array([[0.]]),
#  array([[0.01058893]]),
#  array([[0.01840512]]),
#  array([[0.00889071]]),
#  array([[0.00326236]]),
#  array([[0.00444833]]),
#  array([[0.0123304]]),
#  array([[0.0116478]]),
#  array([[0.]]),
#  array([[0.02177472]]),
#  array([[0.]]),
#  array([[0.01661514]]),
#  array([[0.00354234]]),
#  array([[0.00927246]]),
#  array([[0.10506526]]),
#  array([[0.0131267]]),
#  array([[0.02387848]]),
#  array([[0.02076207]]),
#  array([[0.00706415]]),
#  array([[0.00362128]]),
#  array([[0.0203969]]),
#  array([[0.01194572]]),
#  array([[0.01305484]]),
#  array([[0.02193517]]),
#  array([[0.06794926]]),
#  array([[0.02165467]]),
#  array([[0.00240703]]),
#  array([[0.]]),
#  array([[0.06879113]]),
#  array([[0.02956962]]),
#  array([[0.0287229]]),
#  array([[0.00589818]]),
#  array([[0.01963383]]),
#  array([[0.01500405]]),
#  array([[0.]]),
#  array([[0.0164529]]),
#  array([[0.02569924]]),
#  array([[0.01140584]]),
#  array([[0.]]),
#  array([[0.00710399]]),
#  array([[0.]]),
#  array([[0.0152183]]),
#  array([[0.0054685]]),
#  array([[0.01004322]]),
#  array([[0.01074108]]),
#  array([[0.00905627]]),
#  array([[0.0977578]]),
#  array([[0.0727889]]),
#  array([[0.]]),
#  array([[0.01974654]]),
#  array([[0.02138482]]),
#  array([[0.00819925]]),
#  array([[0.13756261]]),
#  array([[0.00947683]]),
#  array([[0.03005544]]),
#  array([[0.02780258]]),
#  array([[0.00593785]]),
#  array([[0.01381839]]),
#  array([[0.02289134]]),
#  array([[0.02407013]]),
#  array([[0.02130842]]),
#  array([[0.]]),
#  array([[0.00681584]]),
#  array([[0.00996726]]),
#  array([[0.01527909]]),
#  array([[0.03082844]]),
#  array([[0.]]),
#  array([[0.01105621]]),
#  array([[0.0055318]]),
#  array([[0.02598964]]),
#  array([[0.05921508]]),
#  array([[0.00749086]]),
#  array([[0.02467199]]),
#  array([[0.]]),
#  array([[0.01479379]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.0094584]]),
#  array([[0.02612502]]),
#  array([[0.00877008]]),
#  array([[0.01598737]]),
#  array([[0.]]),
#  array([[0.01603592]]),
#  array([[0.00829364]]),
#  array([[0.01015813]]),
#  array([[0.02048775]]),
#  array([[0.05703606]]),
#  array([[0.0410509]]),
#  array([[0.01517622]]),
#  array([[0.01129919]]),
#  array([[0.00617619]]),
#  array([[0.]]),
#  array([[0.00628411]]),
#  array([[0.00966377]]),
#  array([[0.01564261]]),
#  array([[0.00730114]]),
#  array([[0.01224312]]),
#  array([[0.010314]]),
#  array([[0.00700292]]),
#  array([[0.02657253]]),
#  array([[0.]]),
#  array([[0.01053645]]),
#  array([[0.00489208]]),
#  array([[0.01044392]]),
#  array([[0.00560006]]),
#  array([[0.02125323]]),
#  array([[0.01533695]]),
#  array([[0.01032628]]),
#  array([[0.0320325]]),
#  array([[0.03830661]]),
#  array([[0.]]),
#  array([[0.01386393]]),
#  array([[0.01658747]]),
#  array([[0.00968912]]),
#  array([[0.01701454]]),
#  array([[0.01260036]]),
#  array([[0.00677445]]),
#  array([[0.01123673]]),
#  array([[0.01138719]]),
#  array([[0.01077283]]),
#  array([[0.01311333]]),
#  array([[0.003526]]),
#  array([[0.02227158]]),
#  array([[0.01355234]]),
#  array([[0.00883246]]),
#  array([[0.]]),
#  array([[0.00243803]]),
#  array([[0.00788677]]),
#  array([[0.00826813]]),
#  array([[0.05227692]]),
#  array([[0.00886406]]),
#  array([[0.00828006]]),
#  array([[0.00421315]]),
#  array([[0.00834914]]),
#  array([[0.0246043]]),
#  array([[0.06011523]]),
#  array([[0.00975415]]),
#  array([[0.00400748]]),
#  array([[0.00972823]]),
#  array([[0.0256946]]),
#  array([[0.]]),
#  array([[0.01039201]]),
#  array([[0.00747108]]),
#  array([[0.01268292]]),
#  array([[0.02107705]]),
#  array([[0.05454189]]),
#  array([[0.00751635]]),
#  array([[0.06707282]]),
#  array([[0.01371348]]),
#  array([[0.01236258]]),
#  array([[0.0284027]]),
#  array([[0.00640889]]),
#  array([[0.04621557]]),
#  array([[0.00524211]]),
#  array([[0.]]),
#  array([[0.02081019]]),
#  array([[0.0061823]]),
#  array([[0.01337307]]),
#  array([[0.01920386]]),
#  array([[0.01881817]]),
#  array([[0.02972798]]),
#  array([[0.00994324]]),
#  array([[0.00897182]]),
#  array([[0.01024047]]),
#  array([[0.0057763]]),
#  array([[0.00177023]]),
#  array([[0.01567217]]),
#  array([[0.0366725]]),
#  array([[0.01938694]]),
#  array([[0.02111418]]),
#  array([[0.00318057]]),
#  array([[0.01404953]]),
#  array([[0.03482763]]),
#  array([[0.]]),
#  array([[0.00281757]]),
#  array([[0.00727036]]),
#  array([[0.01154364]]),
#  array([[0.]]),
#  array([[0.0051415]]),
#  array([[0.03342831]]),
#  array([[0.00879226]]),
#  array([[0.00797446]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01211177]]),
#  array([[0.01386736]]),
#  array([[0.00830325]]),
#  array([[0.00531056]]),
#  array([[0.01406774]]),
#  array([[0.00456816]]),
#  array([[0.00195474]]),
#  array([[0.01194315]]),
#  array([[0.01343887]]),
#  array([[0.01798013]]),
#  array([[0.02232431]]),
#  array([[0.00746381]]),
#  array([[0.00662792]]),
#  array([[0.]]),
#  array([[0.02850254]]),
#  array([[0.01464334]]),
#  array([[0.00371371]]),
#  array([[0.0095399]]),
#  array([[0.00768118]]),
#  array([[0.00413212]]),
#  array([[0.02569894]]),
#  array([[0.00483276]]),
#  array([[0.0784976]]),
#  array([[0.00696178]]),
#  array([[0.00716883]]),
#  array([[0.00816042]]),
#  array([[0.01500747]]),
#  array([[0.01639465]]),
#  array([[0.00298502]]),
#  array([[0.00205674]]),
#  array([[0.01018665]]),
#  array([[0.01058379]]),
#  array([[0.]]),
#  array([[0.00701037]]),
#  array([[0.]]),
#  array([[0.00576194]]),
#  array([[0.]]),
#  array([[0.02380804]]),
#  array([[0.00395]]),
#  array([[0.30811716]]),
#  array([[0.00384785]]),
#  array([[0.01206579]]),
#  array([[0.01771587]]),
#  array([[0.01540191]]),
#  array([[0.00914677]]),
#  array([[0.0121116]]),
#  array([[0.01765095]]),
#  array([[0.]]),
#  array([[0.01260399]]),
#  array([[0.]]),
#  array([[0.00260391]]),
#  array([[0.00753874]]),
#  array([[0.]]),
#  array([[0.02547366]]),
#  array([[0.01318007]]),
#  array([[0.01855728]]),
#  array([[0.0092424]]),
#  array([[0.02028429]]),
#  array([[0.01898733]]),
#  array([[0.01349933]]),
#  array([[0.00869459]]),
#  array([[0.02272684]]),
#  array([[0.02823698]]),
#  array([[0.]]),
#  array([[0.03562089]]),
#  array([[0.01398683]]),
#  array([[0.00889718]]),
#  array([[0.01022927]]),
#  array([[0.01956004]]),
#  array([[0.12974723]]),
#  array([[0.01288836]]),
#  array([[0.00861714]]),
#  array([[0.]]),
#  array([[0.00850622]]),
#  array([[0.00492574]]),
#  array([[0.01241775]]),
#  array([[0.02026009]]),
#  array([[0.00641783]]),
#  array([[0.00406281]]),
#  array([[0.00765106]]),
#  array([[0.29178861]]),
#  array([[0.]]),
#  array([[0.00506316]]),
#  array([[0.00924258]]),
#  array([[0.012773]]),
#  array([[0.00982308]]),
#  array([[0.00884999]]),
#  array([[0.00589807]]),
#  array([[0.00717021]]),
#  array([[0.01799122]]),
#  array([[0.00718118]]),
#  array([[0.01263029]]),
#  array([[0.00338034]]),
#  array([[0.00313693]]),
#  array([[0.13288765]]),
#  array([[0.03442014]]),
#  array([[0.0095566]]),
#  array([[0.00850533]]),
#  array([[0.01009515]]),
#  array([[0.01048078]]),
#  array([[0.00617334]]),
#  array([[0.00585373]]),
#  array([[0.08016605]]),
#  array([[0.00912796]]),
#  array([[0.]]),
#  array([[0.005448]]),
#  array([[0.01566502]]),
#  array([[0.00492924]]),
#  array([[0.00524162]]),
#  array([[0.00992901]]),
#  array([[0.11486694]]),
#  array([[0.01080794]]),
#  array([[0.]]),
#  array([[0.01553342]]),
#  array([[0.]]),
#  array([[0.01729085]]),
#  array([[0.02258978]]),
#  array([[0.0155651]]),
#  array([[0.02532415]]),
#  array([[0.00874435]]),
#  array([[0.00553639]]),
#  array([[0.00416031]]),
#  array([[0.00866644]]),
#  array([[0.00420294]]),
#  array([[0.00910756]]),
#  array([[0.00318747]]),
#  array([[0.01551117]]),
#  array([[0.]]),
#  array([[0.01530715]]),
#  array([[0.]]),
#  array([[0.01043176]]),
#  array([[0.]]),
#  array([[0.01942857]]),
#  array([[0.03716251]]),
#  array([[0.0167134]]),
#  array([[0.00679102]]),
#  array([[0.14214749]]),
#  array([[0.01160074]]),
#  array([[0.]]),
#  array([[0.0265879]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.00384363]]),
#  array([[0.00955758]]),
#  array([[0.00881454]]),
#  array([[0.00432433]]),
#  array([[0.00890432]]),
#  array([[0.]]),
#  array([[0.01337307]]),
#  array([[0.03561224]]),
#  array([[0.02430742]]),
#  array([[0.00764717]]),
#  array([[0.01706003]]),
#  array([[0.00870239]]),
#  array([[0.02775974]]),
#  array([[0.03247386]]),
#  array([[0.00774352]]),
#  array([[0.00642988]]),
#  array([[0.05879868]]),
#  array([[0.]]),
#  array([[0.02515463]]),
#  array([[0.0094685]]),
#  array([[0.01168578]]),
#  array([[0.02030868]]),
#  array([[0.00994693]]),
#  array([[0.01185162]]),
#  array([[0.00863122]]),
#  array([[0.]]),
#  array([[0.00361813]]),
#  array([[0.00617995]]),
#  array([[0.01544429]]),
#  array([[0.01287643]]),
#  array([[0.01142929]]),
#  array([[0.05693137]]),
#  array([[0.01569474]]),
#  array([[0.01030883]]),
#  array([[0.00680959]]),
#  array([[0.00683747]]),
#  array([[0.01195059]]),
#  array([[0.]]),
#  array([[0.02149956]]),
#  array([[0.00576372]]),
#  array([[0.01204718]]),
#  array([[0.0072604]]),
#  array([[0.]]),
#  array([[0.02620628]]),
#  array([[0.00961393]]),
#  array([[0.00712989]]),
#  array([[0.02870527]]),
#  array([[0.00692965]]),
#  array([[0.01098931]]),
#  array([[0.00887417]]),
#  array([[0.]]),
#  array([[0.00929745]]),
#  array([[0.00910386]]),
#  array([[0.0249905]]),
#  array([[0.00707781]]),
#  array([[0.01609529]]),
#  array([[0.00949345]]),
#  array([[0.00975058]]),
#  array([[0.02424543]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01282052]]),
#  array([[0.01387405]]),
#  array([[0.11568271]]),
#  array([[0.01837763]]),
#  array([[0.00606288]]),
#  array([[0.01140349]]),
#  array([[0.00685386]]),
#  array([[0.00542734]]),
#  array([[0.0542178]]),
#  array([[0.01750753]]),
#  array([[0.00613881]]),
#  array([[0.007038]]),
#  array([[0.00306524]]),
#  array([[0.00944489]]),
#  array([[0.06076143]]),
#  array([[0.03158825]]),
#  array([[0.00537959]]),
#  array([[0.04701475]]),
#  array([[0.02230139]]),
#  array([[0.00726009]]),
#  array([[0.]]),
#  array([[0.00734892]]),
#  array([[0.1608698]]),
#  array([[0.00639689]]),
#  array([[0.00764491]]),
#  array([[0.01600181]]),
#  array([[0.]]),
#  array([[0.00754164]]),
#  array([[0.0182048]]),
#  array([[0.07739295]]),
#  array([[0.03273189]]),
#  array([[0.00337109]]),
#  array([[0.016681]]),
#  array([[0.02865265]]),
#  array([[0.0087243]]),
#  array([[0.01258541]]),
#  array([[0.01236282]]),
#  array([[0.00884642]]),
#  array([[0.01089792]]),
#  array([[0.14437438]]),
#  array([[0.05461461]]),
#  array([[0.00333435]]),
#  array([[0.]]),
#  array([[0.03050083]]),
#  array([[0.00674624]]),
#  array([[0.02253107]]),
#  array([[0.00953037]]),
#  array([[0.01324036]]),
#  array([[0.0039784]]),
#  array([[0.]]),
#  array([[0.00734943]]),
#  array([[0.]]),
#  array([[0.0046817]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.00961792]]),
#  array([[0.00661927]]),
#  array([[0.00772125]]),
#  array([[0.0114676]]),
#  array([[0.]]),
#  array([[0.01460755]]),
#  array([[0.0086807]]),
#  array([[0.00398766]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01264356]]),
#  array([[0.00440025]]),
#  array([[0.01040378]]),
#  array([[0.00225481]]),
#  array([[0.00709204]]),
#  array([[0.00415492]]),
#  array([[0.00717983]]),
#  array([[0.00679303]]),
#  array([[0.00763496]]),
#  array([[0.01183903]]),
#  array([[0.03392439]]),
#  array([[0.]]),
#  array([[0.00780697]]),
#  array([[0.02354919]]),
#  array([[0.00527522]]),
#  array([[0.01062246]]),
#  array([[0.00439455]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.00201609]]),
#  array([[0.00493127]]),
#  array([[0.00918294]]),
#  array([[0.01051513]]),
#  array([[0.01163925]]),
#  array([[0.00659299]]),
#  array([[0.]]),
#  array([[0.02713537]]),
#  array([[0.02005542]]),
#  array([[0.21184136]]),
#  array([[0.01050037]]),
#  array([[0.0107834]]),
#  array([[0.]]),
#  array([[0.02745479]]),
#  array([[0.04565405]]),
#  array([[0.06449772]]),
#  array([[0.00497548]]),
#  array([[0.01845812]]),
#  array([[0.00705806]]),
#  array([[0.00729026]]),
#  array([[0.]]),
#  array([[0.01324684]]),
#  array([[0.0927053]]),
#  array([[0.]]),
#  array([[0.02699957]]),
#  array([[0.00864317]]),
#  array([[0.00665249]]),
#  array([[0.00944674]]),
#  array([[0.0104306]]),
#  array([[0.00653935]]),
#  array([[0.]]),
#  array([[0.09672095]]),
#  array([[0.00973662]]),
#  array([[0.05943987]]),
#  array([[0.00799449]]),
#  array([[0.01727033]]),
#  array([[0.06939084]]),
#  array([[0.14643998]]),
#  array([[0.]]),
#  array([[0.02001338]]),
#  array([[0.01766322]]),
#  array([[0.0367729]]),
#  array([[0.]]),
#  array([[0.00299619]]),
#  array([[0.02541095]]),
#  array([[0.03005966]]),
#  array([[0.02170626]]),
#  array([[0.02817643]]),
#  array([[0.01659163]]),
#  array([[0.02396133]]),
#  array([[0.02586015]]),
#  array([[0.00529177]]),
#  array([[0.]]),
#  array([[0.05049772]]),
#  array([[0.00721571]]),
#  array([[0.00799455]]),
#  array([[0.01894846]]),
#  array([[0.00699422]]),
#  array([[0.03902433]]),
#  array([[0.00824543]]),
#  array([[0.01328147]]),
#  array([[0.03201564]]),
#  array([[0.00420646]]),
#  array([[0.01407672]]),
#  array([[0.]]),
#  array([[0.00843636]]),
#  array([[0.01023155]]),
#  array([[0.00576019]]),
#  array([[0.01189413]]),
#  array([[0.01904093]]),
#  array([[0.01043058]]),
#  array([[0.01089909]]),
#  array([[0.]]),
#  array([[0.02815667]]),
#  array([[0.00622653]]),
#  array([[0.01221447]]),
#  array([[0.00995087]]),
#  array([[0.00778671]]),
#  array([[0.02637633]]),
#  array([[0.00343754]]),
#  array([[0.03539122]]),
#  array([[0.01997534]]),
#  array([[0.00823278]]),
#  array([[0.00934954]]),
#  array([[0.05602297]]),
#  array([[0.0069748]]),
#  array([[0.0057565]]),
#  array([[0.01869874]]),
#  array([[0.07478816]]),
#  array([[0.01272768]]),
#  array([[0.05378788]]),
#  array([[0.00830033]]),
#  array([[0.00944397]]),
#  array([[0.00789718]]),
#  array([[0.]]),
#  array([[0.03243095]]),
#  array([[0.03970104]]),
#  array([[0.00391612]]),
#  array([[0.0046885]]),
#  array([[0.04278409]]),
#  array([[0.03565098]]),
#  array([[0.11655745]]),
#  array([[0.]]),
#  array([[0.0035226]]),
#  array([[0.00881195]]),
#  array([[0.06694763]]),
#  array([[0.00880609]]),
#  array([[0.]]),
#  array([[0.01411363]]),
#  array([[0.01244334]]),
#  array([[0.]]),
#  array([[0.00606995]]),
#  array([[0.05879444]]),
#  array([[0.00297883]]),
#  array([[0.11348619]]),
#  array([[0.02386789]]),
#  array([[0.]]),
#  array([[0.02000052]]),
#  array([[0.01901917]]),
#  array([[0.01492536]]),
#  array([[0.00396585]]),
#  array([[0.00387026]]),
#  array([[0.00698163]]),
#  array([[0.01286566]]),
#  array([[0.00370428]]),
#  array([[0.00523403]]),
#  array([[0.00819555]]),
#  array([[0.11994505]]),
#  array([[0.00495433]]),
#  array([[0.0114817]]),
#  array([[0.01465166]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.04944145]]),
#  array([[0.0276505]]),
#  array([[0.00525443]]),
#  array([[0.00720956]]),
#  array([[0.00880514]]),
#  array([[0.00760842]]),
#  array([[0.01889952]]),
#  array([[0.00296724]]),
#  array([[0.]]),
#  array([[0.00562226]]),
#  array([[0.00672393]]),
#  array([[0.00366783]]),
#  array([[0.01880913]]),
#  array([[0.00858689]]),
#  array([[0.00861753]]),
#  array([[0.00336819]]),
#  array([[0.01963864]]),
#  array([[0.01232667]]),
#  array([[0.0100778]]),
#  ...]

# %%
top = sorted(range(len(output2)), key=lambda i: output2[i], reverse=True)[:100]
list_scores = [output2[i][0][0] for i in top]
TF=get_recommendation(top,df, list_scores)
TF
# Out:
#     JobID                                              title  \
# 0     600  Senior Data Scientist/Machine Learning Enginee...
# 1     641  Senior Machine Learning Engineer/Expert (Plann...
# 2    3942               Software Engineer Trainee (AI / GIS)
# 3   12794  Vice President, Big Data Analytics & Machine L...
# 4    7357  Associate Data Scientist/ Data Scientist - Top...
# ..    ...                                                ...
# 95  14851             SENIOR ESTATE MANAGER / ESTATE MANAGER
# 96   7276  Chief Data Architect - MNC, Digital Transforma...
# 97   7374                                     Data Scientist
# 98   3109     Director - Artificial Intelligence (AI) & Data
# 99   2546  (Senior) Data Engineer | Multiple Openings | P...
#
#                                   industry  \
# 0                   Information Technology
# 1                   Information Technology
# 2                                   Others
# 3                       Financial Services
# 4   Human Resources Management/Consultancy
# ..                                     ...
# 95       Property Management / Consultancy
# 96  Human Resources Management/Consultancy
# 97                  Information Technology
# 98  Human Resources Management/Consultancy
# 99  Human Resources Management/Consultancy
#
#                                       job description     score
# 0   Job Responsibilities:•Responsible for the algo...  0.308117
# 1   Job Responsibilities:•Responsible for the algo...  0.291789
# 2   To participate in several large-scale Artifici...  0.281831
# 3   Responsibilities:Explore the availability, acc...  0.255755
# 4   Junior Data Scientist focused on machine learn...  0.255316
# ..                                                ...       ...
# 95  Responsibilities Overall monitoring a team of ...  0.125781
# 96  About the ClientOur client is well established...  0.125771
# 97  Job Responsibilities:Develop and implement Mac...  0.125029
# 98  Our Client:Our client is a conglomerate group ...  0.124013
# 99  Data Engineer | FSI | Perm | 40 - 48kDuties:Re...  0.121537
#
# [100 rows x 5 columns]

# %% [markdown]
# # Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def count_vectorize(scraped_data, cv):
    # CountV the scraped data
    count_vectorizer = CountVectorizer()
    count_jobid = count_vectorizer.fit_transform(scraped_data) #fitting and transforming the vector

    # CountV the cv
    user_count = count_vectorizer.transform(cv)
    cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
    output3 = list(cos_similarity_countv)
    return output3
output3 = count_vectorize(df['All'], df2['All'])
output3
# Out:
# [array([[0.03279129]]),
#  array([[0.0151255]]),
#  array([[0.04519045]]),
#  array([[0.03608178]]),
#  array([[0.07871211]]),
#  array([[0.03961453]]),
#  array([[0.]]),
#  array([[0.02699992]]),
#  array([[0.09709831]]),
#  array([[0.03507393]]),
#  array([[0.0192281]]),
#  array([[0.0295519]]),
#  array([[0.01495413]]),
#  array([[0.]]),
#  array([[0.03435365]]),
#  array([[0.03141437]]),
#  array([[0.02201542]]),
#  array([[0.02848725]]),
#  array([[0.01609661]]),
#  array([[0.02789883]]),
#  array([[0.04364098]]),
#  array([[0.03802288]]),
#  array([[0.03926796]]),
#  array([[0.03261062]]),
#  array([[0.05052016]]),
#  array([[0.]]),
#  array([[0.08780925]]),
#  array([[0.01845141]]),
#  array([[0.0547791]]),
#  array([[0.03798247]]),
#  array([[0.12673854]]),
#  array([[0.01756956]]),
#  array([[0.05011563]]),
#  array([[0.02339501]]),
#  array([[0.05317546]]),
#  array([[0.01197369]]),
#  array([[0.03587624]]),
#  array([[0.]]),
#  array([[0.03772466]]),
#  array([[0.07878084]]),
#  array([[0.15580264]]),
#  array([[0.02913583]]),
#  array([[0.04883009]]),
#  array([[0.0425556]]),
#  array([[0.01840292]]),
#  array([[0.]]),
#  array([[0.03571754]]),
#  array([[0.06879295]]),
#  array([[0.1019191]]),
#  array([[0.06748392]]),
#  array([[0.01702822]]),
#  array([[0.03141797]]),
#  array([[0.08655747]]),
#  array([[0.0425639]]),
#  array([[0.02512242]]),
#  array([[0.04857414]]),
#  array([[0.02837593]]),
#  array([[0.04706938]]),
#  array([[0.01641275]]),
#  array([[0.00467652]]),
#  array([[0.07059801]]),
#  array([[0.01782732]]),
#  array([[0.04451352]]),
#  array([[0.01585954]]),
#  array([[0.03856687]]),
#  array([[0.04380291]]),
#  array([[0.03225806]]),
#  array([[0.06226694]]),
#  array([[0.01385685]]),
#  array([[0.04271477]]),
#  array([[0.0211341]]),
#  array([[0.06688908]]),
#  array([[0.05627109]]),
#  array([[0.02731028]]),
#  array([[0.15642479]]),
#  array([[0.0381156]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.04310665]]),
#  array([[0.05354796]]),
#  array([[0.08533544]]),
#  array([[0.03296343]]),
#  array([[0.05415304]]),
#  array([[0.01595136]]),
#  array([[0.05366735]]),
#  array([[0.03834649]]),
#  array([[0.03539407]]),
#  array([[0.01976724]]),
#  array([[0.07625968]]),
#  array([[0.01494982]]),
#  array([[0.10285211]]),
#  array([[0.07755137]]),
#  array([[0.02162194]]),
#  array([[0.06881227]]),
#  array([[0.07469788]]),
#  array([[0.07322827]]),
#  array([[0.02983082]]),
#  array([[0.03499985]]),
#  array([[0.04911026]]),
#  array([[0.02139068]]),
#  array([[0.]]),
#  array([[0.06306363]]),
#  array([[0.04969666]]),
#  array([[0.00814706]]),
#  array([[0.04685356]]),
#  array([[0.04278136]]),
#  array([[0.05309111]]),
#  array([[0.05046473]]),
#  array([[0.]]),
#  array([[0.04324388]]),
#  array([[0.10301071]]),
#  array([[0.05754706]]),
#  array([[0.02537185]]),
#  array([[0.04147807]]),
#  array([[0.02455513]]),
#  array([[0.]]),
#  array([[0.03440614]]),
#  array([[0.01764004]]),
#  array([[0.03661414]]),
#  array([[0.0630291]]),
#  array([[0.01087021]]),
#  array([[0.00855263]]),
#  array([[0.02838824]]),
#  array([[0.01724266]]),
#  array([[0.056561]]),
#  array([[0.03209669]]),
#  array([[0.02932942]]),
#  array([[0.04335713]]),
#  array([[0.04747461]]),
#  array([[0.0468766]]),
#  array([[0.04397655]]),
#  array([[0.04356068]]),
#  array([[0.11214385]]),
#  array([[0.06110075]]),
#  array([[0.06536506]]),
#  array([[0.03379767]]),
#  array([[0.03694074]]),
#  array([[0.02680709]]),
#  array([[0.02568704]]),
#  array([[0.04028706]]),
#  array([[0.0425556]]),
#  array([[0.00711064]]),
#  array([[0.03533238]]),
#  array([[0.04813927]]),
#  array([[0.05041062]]),
#  array([[0.05339983]]),
#  array([[0.02219211]]),
#  array([[0.08662736]]),
#  array([[0.04676524]]),
#  array([[0.06632365]]),
#  array([[0.]]),
#  array([[0.04205394]]),
#  array([[0.05668293]]),
#  array([[0.02533676]]),
#  array([[0.0212778]]),
#  array([[0.0372244]]),
#  array([[0.00721312]]),
#  array([[0.]]),
#  array([[0.05136932]]),
#  array([[0.06143495]]),
#  array([[0.02276405]]),
#  array([[0.10211194]]),
#  array([[0.02348233]]),
#  array([[0.04790658]]),
#  array([[0.05067352]]),
#  array([[0.02105328]]),
#  array([[0.02908802]]),
#  array([[0.04054285]]),
#  array([[0.04637389]]),
#  array([[0.02098929]]),
#  array([[0.0387911]]),
#  array([[0.04022387]]),
#  array([[0.06849109]]),
#  array([[0.04899136]]),
#  array([[0.01933925]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.06256847]]),
#  array([[0.05205131]]),
#  array([[0.01665799]]),
#  array([[0.0115754]]),
#  array([[0.04772957]]),
#  array([[0.]]),
#  array([[0.03980433]]),
#  array([[0.00929961]]),
#  array([[0.0184379]]),
#  array([[0.04204242]]),
#  array([[0.02235385]]),
#  array([[0.05920406]]),
#  array([[0.03606561]]),
#  array([[0.0720023]]),
#  array([[0.04024153]]),
#  array([[0.01761175]]),
#  array([[0.04189918]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.05357177]]),
#  array([[0.09107651]]),
#  array([[0.01644712]]),
#  array([[0.05894019]]),
#  array([[0.23522852]]),
#  array([[0.03358429]]),
#  array([[0.05883167]]),
#  array([[0.03714868]]),
#  array([[0.04308804]]),
#  array([[0.1489853]]),
#  array([[0.01869976]]),
#  array([[0.08525925]]),
#  array([[0.01304712]]),
#  array([[0.00726605]]),
#  array([[0.02610572]]),
#  array([[0.06713924]]),
#  array([[0.]]),
#  array([[0.02402461]]),
#  array([[0.00698056]]),
#  array([[0.11849211]]),
#  array([[0.05982229]]),
#  array([[0.17968304]]),
#  array([[0.03368455]]),
#  array([[0.05732508]]),
#  array([[0.01928035]]),
#  array([[0.03262183]]),
#  array([[0.09878292]]),
#  array([[0.04160027]]),
#  array([[0.06382654]]),
#  array([[0.05445086]]),
#  array([[0.09614051]]),
#  array([[0.06245488]]),
#  array([[0.0620793]]),
#  array([[0.04888237]]),
#  array([[0.01708591]]),
#  array([[0.04123821]]),
#  array([[0.02444119]]),
#  array([[0.04272266]]),
#  array([[0.03137107]]),
#  array([[0.0256579]]),
#  array([[0.0183548]]),
#  array([[0.04891862]]),
#  array([[0.0222773]]),
#  array([[0.]]),
#  array([[0.09562436]]),
#  array([[0.0219605]]),
#  array([[0.0461895]]),
#  array([[0.04795399]]),
#  array([[0.03770733]]),
#  array([[0.02644545]]),
#  array([[0.04637389]]),
#  array([[0.06171534]]),
#  array([[0.]]),
#  array([[0.0069079]]),
#  array([[0.03552847]]),
#  array([[0.02699077]]),
#  array([[0.06712165]]),
#  array([[0.02977952]]),
#  array([[0.09921062]]),
#  array([[0.01750685]]),
#  array([[0.02531578]]),
#  array([[0.0277137]]),
#  array([[0.04707656]]),
#  array([[0.01982442]]),
#  array([[0.02632092]]),
#  array([[0.08633149]]),
#  array([[0.19225006]]),
#  array([[0.02222039]]),
#  array([[0.06818952]]),
#  array([[0.02410864]]),
#  array([[0.03985084]]),
#  array([[0.01774015]]),
#  array([[0.03035884]]),
#  array([[0.01624407]]),
#  array([[0.09505391]]),
#  array([[0.02376326]]),
#  array([[0.27390758]]),
#  array([[0.02016468]]),
#  array([[0.11375046]]),
#  array([[0.06190833]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.08615695]]),
#  array([[0.01271592]]),
#  array([[0.04036329]]),
#  array([[0.]]),
#  array([[0.02150538]]),
#  array([[0.28840895]]),
#  array([[0.07250759]]),
#  array([[0.01986439]]),
#  array([[0.04242776]]),
#  array([[0.05821041]]),
#  array([[0.08077192]]),
#  array([[0.0485351]]),
#  array([[0.12470245]]),
#  array([[0.0243848]]),
#  array([[0.05102735]]),
#  array([[0.03794855]]),
#  array([[0.08957898]]),
#  array([[0.01276399]]),
#  array([[0.3210777]]),
#  array([[0.02182049]]),
#  array([[0.07216356]]),
#  array([[0.03526119]]),
#  array([[0.02595385]]),
#  array([[0.05726558]]),
#  array([[0.00979827]]),
#  array([[0.01437993]]),
#  array([[0.03074559]]),
#  array([[0.03180078]]),
#  array([[0.03001248]]),
#  array([[0.04621696]]),
#  array([[0.]]),
#  array([[0.03985084]]),
#  array([[0.05481896]]),
#  array([[0.00951238]]),
#  array([[0.04786497]]),
#  array([[0.04882704]]),
#  array([[0.]]),
#  array([[0.01763296]]),
#  array([[0.05458113]]),
#  array([[0.]]),
#  array([[0.02030378]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.02888356]]),
#  array([[0.0564445]]),
#  array([[0.04307083]]),
#  array([[0.]]),
#  array([[0.02023922]]),
#  array([[0.05968451]]),
#  array([[0.]]),
#  array([[0.27989465]]),
#  array([[0.02788015]]),
#  array([[0.01353826]]),
#  array([[0.02839809]]),
#  array([[0.0413405]]),
#  array([[0.0516092]]),
#  array([[0.11220664]]),
#  array([[0.17574237]]),
#  array([[0.06501018]]),
#  array([[0.03421053]]),
#  array([[0.05020121]]),
#  array([[0.0779747]]),
#  array([[0.03916719]]),
#  array([[0.030676]]),
#  array([[0.0228099]]),
#  array([[0.06253837]]),
#  array([[0.03566441]]),
#  array([[0.01809677]]),
#  array([[0.04008088]]),
#  array([[0.01818416]]),
#  array([[0.06276875]]),
#  array([[0.02506798]]),
#  array([[0.3015825]]),
#  array([[0.02265693]]),
#  array([[0.04144988]]),
#  array([[0.05086237]]),
#  array([[0.03328816]]),
#  array([[0.]]),
#  array([[0.07074999]]),
#  array([[0.0520893]]),
#  array([[0.00837414]]),
#  array([[0.10625593]]),
#  array([[0.05275078]]),
#  array([[0.06412942]]),
#  array([[0.09677419]]),
#  array([[0.]]),
#  array([[0.04052737]]),
#  array([[0.06827569]]),
#  array([[0.04763086]]),
#  array([[0.08452313]]),
#  array([[0.06180642]]),
#  array([[0.07012409]]),
#  array([[0.03919309]]),
#  array([[0.04899136]]),
#  array([[0.]]),
#  array([[0.04973709]]),
#  array([[0.05300883]]),
#  array([[0.]]),
#  array([[0.01921893]]),
#  array([[0.02233924]]),
#  array([[0.02294912]]),
#  array([[0.01750685]]),
#  array([[0.02358333]]),
#  array([[0.05697451]]),
#  array([[0.06069998]]),
#  array([[0.]]),
#  array([[0.07761992]]),
#  array([[0.]]),
#  array([[0.03208602]]),
#  array([[0.01798302]]),
#  array([[0.04366354]]),
#  array([[0.17397607]]),
#  array([[0.05932168]]),
#  array([[0.081539]]),
#  array([[0.08997856]]),
#  array([[0.03610202]]),
#  array([[0.03285219]]),
#  array([[0.07838618]]),
#  array([[0.0229961]]),
#  array([[0.02527898]]),
#  array([[0.07934065]]),
#  array([[0.13708946]]),
#  array([[0.08227502]]),
#  array([[0.01375488]]),
#  array([[0.]]),
#  array([[0.10820574]]),
#  array([[0.06066954]]),
#  array([[0.11106744]]),
#  array([[0.03961453]]),
#  array([[0.09120957]]),
#  array([[0.06000465]]),
#  array([[0.0060962]]),
#  array([[0.08534682]]),
#  array([[0.03736016]]),
#  array([[0.05841595]]),
#  array([[0.0106389]]),
#  array([[0.04035056]]),
#  array([[0.]]),
#  array([[0.03834649]]),
#  array([[0.02887579]]),
#  array([[0.02572361]]),
#  array([[0.06167671]]),
#  array([[0.03576247]]),
#  array([[0.21621938]]),
#  array([[0.07490059]]),
#  array([[0.01432266]]),
#  array([[0.03904463]]),
#  array([[0.02687369]]),
#  array([[0.03574987]]),
#  array([[0.33930679]]),
#  array([[0.03750128]]),
#  array([[0.12749295]]),
#  array([[0.08740748]]),
#  array([[0.03114751]]),
#  array([[0.06334191]]),
#  array([[0.02815715]]),
#  array([[0.02966084]]),
#  array([[0.05162854]]),
#  array([[0.]]),
#  array([[0.03405643]]),
#  array([[0.05915387]]),
#  array([[0.07531101]]),
#  array([[0.0677247]]),
#  array([[0.]]),
#  array([[0.04637389]]),
#  array([[0.01381579]]),
#  array([[0.14767008]]),
#  array([[0.0887308]]),
#  array([[0.00794527]]),
#  array([[0.06863758]]),
#  array([[0.]]),
#  array([[0.07061347]]),
#  array([[0.00990196]]),
#  array([[0.0152614]]),
#  array([[0.03438721]]),
#  array([[0.08994156]]),
#  array([[0.03745029]]),
#  array([[0.06274215]]),
#  array([[0.]]),
#  array([[0.04595037]]),
#  array([[0.02166121]]),
#  array([[0.03007377]]),
#  array([[0.0237893]]),
#  array([[0.07637594]]),
#  array([[0.13376707]]),
#  array([[0.0515417]]),
#  array([[0.05882856]]),
#  array([[0.0186242]]),
#  array([[0.]]),
#  array([[0.05415304]]),
#  array([[0.06870729]]),
#  array([[0.05361419]]),
#  array([[0.02304337]]),
#  array([[0.06211779]]),
#  array([[0.05273393]]),
#  array([[0.02644943]]),
#  array([[0.05022059]]),
#  array([[0.01242356]]),
#  array([[0.0652725]]),
#  array([[0.0180056]]),
#  array([[0.02697453]]),
#  array([[0.01475101]]),
#  array([[0.09600307]]),
#  array([[0.05659843]]),
#  array([[0.02900887]]),
#  array([[0.07400115]]),
#  array([[0.15886771]]),
#  array([[0.]]),
#  array([[0.0658465]]),
#  array([[0.08826453]]),
#  array([[0.06276875]]),
#  array([[0.0328351]]),
#  array([[0.0417927]]),
#  array([[0.03111828]]),
#  array([[0.06023557]]),
#  array([[0.04943473]]),
#  array([[0.03449415]]),
#  array([[0.04986685]]),
#  array([[0.01030107]]),
#  array([[0.04586706]]),
#  array([[0.04464052]]),
#  array([[0.0601363]]),
#  array([[0.]]),
#  array([[0.01782245]]),
#  array([[0.01671199]]),
#  array([[0.04813927]]),
#  array([[0.07838618]]),
#  array([[0.01040426]]),
#  array([[0.05714006]]),
#  array([[0.01950964]]),
#  array([[0.03022421]]),
#  array([[0.03147581]]),
#  array([[0.09181732]]),
#  array([[0.03680583]]),
#  array([[0.03273074]]),
#  array([[0.05506154]]),
#  array([[0.07180652]]),
#  array([[0.01087021]]),
#  array([[0.03941899]]),
#  array([[0.02011193]]),
#  array([[0.02231547]]),
#  array([[0.09022131]]),
#  array([[0.15825093]]),
#  array([[0.03316183]]),
#  array([[0.12068254]]),
#  array([[0.03586372]]),
#  array([[0.0441786]]),
#  array([[0.02855719]]),
#  array([[0.02198333]]),
#  array([[0.0615037]]),
#  array([[0.01007177]]),
#  array([[0.01067643]]),
#  array([[0.04529945]]),
#  array([[0.0205347]]),
#  array([[0.06465791]]),
#  array([[0.06492345]]),
#  array([[0.0739032]]),
#  array([[0.05395321]]),
#  array([[0.04390462]]),
#  array([[0.04067259]]),
#  array([[0.05578088]]),
#  array([[0.02004918]]),
#  array([[0.00906277]]),
#  array([[0.04536664]]),
#  array([[0.08379835]]),
#  array([[0.08662736]]),
#  array([[0.1357115]]),
#  array([[0.0182127]]),
#  array([[0.04127222]]),
#  array([[0.09795001]]),
#  array([[0.00675953]]),
#  array([[0.02859738]]),
#  array([[0.02833177]]),
#  array([[0.02671468]]),
#  array([[0.00892466]]),
#  array([[0.03493083]]),
#  array([[0.08715302]]),
#  array([[0.03272591]]),
#  array([[0.03068943]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.04285742]]),
#  array([[0.03413322]]),
#  array([[0.04077728]]),
#  array([[0.02219211]]),
#  array([[0.07473499]]),
#  array([[0.02922827]]),
#  array([[0.01155741]]),
#  array([[0.0595319]]),
#  array([[0.05166849]]),
#  array([[0.04741968]]),
#  array([[0.08509763]]),
#  array([[0.03460513]]),
#  array([[0.01069534]]),
#  array([[0.00833797]]),
#  array([[0.07408341]]),
#  array([[0.0564445]]),
#  array([[0.03322481]]),
#  array([[0.06730993]]),
#  array([[0.01895841]]),
#  array([[0.02775503]]),
#  array([[0.03949516]]),
#  array([[0.01412203]]),
#  array([[0.1493611]]),
#  array([[0.0300387]]),
#  array([[0.01893206]]),
#  array([[0.03219322]]),
#  array([[0.05171582]]),
#  array([[0.04054285]]),
#  array([[0.0238826]]),
#  array([[0.01124732]]),
#  array([[0.05039226]]),
#  array([[0.02804964]]),
#  array([[0.]]),
#  array([[0.02294912]]),
#  array([[0.]]),
#  array([[0.01631091]]),
#  array([[0.]]),
#  array([[0.09108979]]),
#  array([[0.01091025]]),
#  array([[0.34260652]]),
#  array([[0.03208602]]),
#  array([[0.03957178]]),
#  array([[0.03085883]]),
#  array([[0.05037014]]),
#  array([[0.02522718]]),
#  array([[0.04429975]]),
#  array([[0.03614769]]),
#  array([[0.00942683]]),
#  array([[0.05703432]]),
#  array([[0.]]),
#  array([[0.00576084]]),
#  array([[0.02056834]]),
#  array([[0.]]),
#  array([[0.14424384]]),
#  array([[0.06394118]]),
#  array([[0.05385412]]),
#  array([[0.03025099]]),
#  array([[0.0644949]]),
#  array([[0.06115607]]),
#  array([[0.07440304]]),
#  array([[0.02496686]]),
#  array([[0.03026292]]),
#  array([[0.0646466]]),
#  array([[0.]]),
#  array([[0.05369732]]),
#  array([[0.06818326]]),
#  array([[0.03097334]]),
#  array([[0.01487698]]),
#  array([[0.03858541]]),
#  array([[0.17590619]]),
#  array([[0.03628575]]),
#  array([[0.04090399]]),
#  array([[0.]]),
#  array([[0.02485372]]),
#  array([[0.01500624]]),
#  array([[0.03213391]]),
#  array([[0.04228546]]),
#  array([[0.01771855]]),
#  array([[0.02030378]]),
#  array([[0.02449796]]),
#  array([[0.36472311]]),
#  array([[0.]]),
#  array([[0.03488962]]),
#  array([[0.02804964]]),
#  array([[0.01825708]]),
#  array([[0.03885473]]),
#  array([[0.05373486]]),
#  array([[0.02875987]]),
#  array([[0.02249464]]),
#  array([[0.03868473]]),
#  array([[0.0243848]]),
#  array([[0.02032183]]),
#  array([[0.01277206]]),
#  array([[0.02011193]]),
#  array([[0.32587853]]),
#  array([[0.09450855]]),
#  array([[0.02965242]]),
#  array([[0.04295843]]),
#  array([[0.07055563]]),
#  array([[0.05935541]]),
#  array([[0.0240276]]),
#  array([[0.0150325]]),
#  array([[0.11336586]]),
#  array([[0.04259714]]),
#  array([[0.]]),
#  array([[0.02490677]]),
#  array([[0.06272089]]),
#  array([[0.0130043]]),
#  array([[0.03983042]]),
#  array([[0.04444079]]),
#  array([[0.34398385]]),
#  array([[0.05360877]]),
#  array([[0.]]),
#  array([[0.03884777]]),
#  array([[0.]]),
#  array([[0.04371525]]),
#  array([[0.09640226]]),
#  array([[0.07166319]]),
#  array([[0.08647222]]),
#  array([[0.04012087]]),
#  array([[0.01517942]]),
#  array([[0.02080851]]),
#  array([[0.04356068]]),
#  array([[0.02564155]]),
#  array([[0.06551437]]),
#  array([[0.02742501]]),
#  array([[0.03509717]]),
#  array([[0.]]),
#  array([[0.03159613]]),
#  array([[0.]]),
#  array([[0.07140627]]),
#  array([[0.]]),
#  array([[0.06749202]]),
#  array([[0.06041896]]),
#  array([[0.04424259]]),
#  array([[0.04981355]]),
#  array([[0.30084811]]),
#  array([[0.02358333]]),
#  array([[0.]]),
#  array([[0.0996271]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.02008048]]),
#  array([[0.04228642]]),
#  array([[0.03478042]]),
#  array([[0.02757048]]),
#  array([[0.0243848]]),
#  array([[0.01081097]]),
#  array([[0.03114751]]),
#  array([[0.0851112]]),
#  array([[0.08980265]]),
#  array([[0.02804964]]),
#  array([[0.08218816]]),
#  array([[0.04008088]]),
#  array([[0.02797393]]),
#  array([[0.08546176]]),
#  array([[0.03916719]]),
#  array([[0.01805101]]),
#  array([[0.10312852]]),
#  array([[0.]]),
#  array([[0.06394568]]),
#  array([[0.02546376]]),
#  array([[0.04821727]]),
#  array([[0.07409949]]),
#  array([[0.05570647]]),
#  array([[0.01655155]]),
#  array([[0.03114751]]),
#  array([[0.]]),
#  array([[0.00792977]]),
#  array([[0.01699008]]),
#  array([[0.02960203]]),
#  array([[0.06644962]]),
#  array([[0.0418281]]),
#  array([[0.13036942]]),
#  array([[0.03449415]]),
#  array([[0.03713854]]),
#  array([[0.00902551]]),
#  array([[0.03786412]]),
#  array([[0.02666311]]),
#  array([[0.]]),
#  array([[0.09541589]]),
#  array([[0.03647231]]),
#  array([[0.03661414]]),
#  array([[0.02368565]]),
#  array([[0.]]),
#  array([[0.0508208]]),
#  array([[0.02742501]]),
#  array([[0.02154402]]),
#  array([[0.10709591]]),
#  array([[0.02358333]]),
#  array([[0.04364098]]),
#  array([[0.03886141]]),
#  array([[0.]]),
#  array([[0.02599157]]),
#  array([[0.05116981]]),
#  array([[0.07812091]]),
#  array([[0.0228099]]),
#  array([[0.06068301]]),
#  array([[0.05425177]]),
#  array([[0.02669991]]),
#  array([[0.0792205]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.10476976]]),
#  array([[0.05833309]]),
#  array([[0.2466878]]),
#  array([[0.08183917]]),
#  array([[0.03401823]]),
#  array([[0.04680933]]),
#  array([[0.02872919]]),
#  array([[0.01662228]]),
#  array([[0.05772733]]),
#  array([[0.06039499]]),
#  array([[0.0184758]]),
#  array([[0.02190146]]),
#  array([[0.0183548]]),
#  array([[0.0081808]]),
#  array([[0.20190285]]),
#  array([[0.05294851]]),
#  array([[0.01687719]]),
#  array([[0.06050198]]),
#  array([[0.12252513]]),
#  array([[0.02896954]]),
#  array([[0.]]),
#  array([[0.04197062]]),
#  array([[0.30199417]]),
#  array([[0.03516943]]),
#  array([[0.01854956]]),
#  array([[0.05303335]]),
#  array([[0.]]),
#  array([[0.0151255]]),
#  array([[0.04527829]]),
#  array([[0.29460652]]),
#  array([[0.07868744]]),
#  array([[0.01909183]]),
#  array([[0.05663907]]),
#  array([[0.07472032]]),
#  array([[0.02249464]]),
#  array([[0.03709911]]),
#  array([[0.02715377]]),
#  array([[0.04445894]]),
#  array([[0.03628575]]),
#  array([[0.36139978]]),
#  array([[0.09857946]]),
#  array([[0.02654555]]),
#  array([[0.]]),
#  array([[0.05198313]]),
#  array([[0.01590611]]),
#  array([[0.09642919]]),
#  array([[0.0468766]]),
#  array([[0.05520875]]),
#  array([[0.00988695]]),
#  array([[0.]]),
#  array([[0.03790363]]),
#  array([[0.]]),
#  array([[0.02556416]]),
#  array([[0.01251369]]),
#  array([[0.]]),
#  array([[0.02414492]]),
#  array([[0.01013975]]),
#  array([[0.04226007]]),
#  array([[0.04772407]]),
#  array([[0.]]),
#  array([[0.04513703]]),
#  array([[0.05435933]]),
#  array([[0.02150538]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.02421797]]),
#  array([[0.02109357]]),
#  array([[0.02797393]]),
#  array([[0.01498012]]),
#  array([[0.01983409]]),
#  array([[0.01587502]]),
#  array([[0.02014353]]),
#  array([[0.04833839]]),
#  array([[0.01837881]]),
#  array([[0.0151734]]),
#  array([[0.05314354]]),
#  array([[0.]]),
#  array([[0.02514977]]),
#  array([[0.08009974]]),
#  array([[0.03890469]]),
#  array([[0.03896186]]),
#  array([[0.00984231]]),
#  array([[0.]]),
#  array([[0.]]),
#  array([[0.01183639]]),
#  array([[0.01419905]]),
#  array([[0.03106006]]),
#  array([[0.02362864]]),
#  array([[0.0707744]]),
#  array([[0.04734842]]),
#  array([[0.]]),
#  array([[0.13239679]]),
#  array([[0.071683]]),
#  array([[0.39531716]]),
#  array([[0.02162194]]),
#  array([[0.03619354]]),
#  array([[0.]]),
#  array([[0.03492625]]),
#  array([[0.08940441]]),
#  array([[0.17932877]]),
#  array([[0.03940212]]),
#  array([[0.02667536]]),
#  array([[0.04525628]]),
#  array([[0.02975397]]),
#  array([[0.]]),
#  array([[0.0302153]]),
#  array([[0.12850734]]),
#  array([[0.]]),
#  array([[0.04686463]]),
#  array([[0.03408529]]),
#  array([[0.03014428]]),
#  array([[0.05291672]]),
#  array([[0.05004506]]),
#  array([[0.01270796]]),
#  array([[0.]]),
#  array([[0.23658371]]),
#  array([[0.03929719]]),
#  array([[0.05977626]]),
#  array([[0.02942768]]),
#  array([[0.08662736]]),
#  array([[0.20447461]]),
#  array([[0.29457662]]),
#  array([[0.]]),
#  array([[0.06374445]]),
#  array([[0.08591323]]),
#  array([[0.10922056]]),
#  array([[0.]]),
#  array([[0.01809677]]),
#  array([[0.05703432]]),
#  array([[0.03796974]]),
#  array([[0.10122588]]),
#  array([[0.06514969]]),
#  array([[0.02979659]]),
#  array([[0.08697351]]),
#  array([[0.09991788]]),
#  array([[0.01564746]]),
#  array([[0.]]),
#  array([[0.20223031]]),
#  array([[0.02077369]]),
#  array([[0.02232026]]),
#  array([[0.04824143]]),
#  array([[0.02407252]]),
#  array([[0.14944064]]),
#  array([[0.0546381]]),
#  array([[0.04116098]]),
#  array([[0.04111781]]),
#  array([[0.02628566]]),
#  array([[0.03560907]]),
#  array([[0.]]),
#  array([[0.02578982]]),
#  array([[0.0600774]]),
#  array([[0.03014428]]),
#  array([[0.05012933]]),
#  array([[0.04516858]]),
#  array([[0.02360595]]),
#  array([[0.04372172]]),
#  array([[0.]]),
#  array([[0.07315441]]),
#  array([[0.01975146]]),
#  array([[0.05506441]]),
#  array([[0.04154737]]),
#  array([[0.00974047]]),
#  array([[0.02686743]]),
#  array([[0.03819565]]),
#  array([[0.11463932]]),
#  array([[0.03554779]]),
#  array([[0.00597689]]),
#  array([[0.03025099]]),
#  array([[0.1038154]]),
#  array([[0.03096694]]),
#  array([[0.01793812]]),
#  array([[0.03865983]]),
#  array([[0.2772549]]),
#  array([[0.0662062]]),
#  array([[0.08557486]]),
#  array([[0.02290243]]),
#  array([[0.04779298]]),
#  array([[0.02481745]]),
#  array([[0.]]),
#  array([[0.08824075]]),
#  array([[0.13200422]]),
#  array([[0.0210573]]),
#  array([[0.01554456]]),
#  array([[0.04992033]]),
#  array([[0.18067758]]),
#  array([[0.14462577]]),
#  array([[0.]]),
#  array([[0.0186242]]),
#  array([[0.03690282]]),
#  array([[0.26951798]]),
#  array([[0.01527519]]),
#  array([[0.]]),
#  array([[0.02203382]]),
#  array([[0.04047845]]),
#  array([[0.]]),
#  array([[0.02580645]]),
#  array([[0.10709591]]),
#  array([[0.0151255]]),
#  array([[0.1751182]]),
#  array([[0.07582191]]),
#  array([[0.]]),
#  array([[0.04371525]]),
#  array([[0.0469406]]),
#  array([[0.05043819]]),
#  array([[0.02107541]]),
#  array([[0.02405452]]),
#  array([[0.02162194]]),
#  array([[0.04214268]]),
#  array([[0.01033512]]),
#  array([[0.02808772]]),
#  array([[0.02690509]]),
#  array([[0.28691987]]),
#  array([[0.01101749]]),
#  array([[0.06170502]]),
#  array([[0.06263608]]),
#  array([[0.]]),
#  array([[0.00867143]]),
#  array([[0.22008391]]),
#  array([[0.10413888]]),
#  array([[0.01653401]]),
#  array([[0.01880194]]),
#  array([[0.03339797]]),
#  array([[0.02738955]]),
#  array([[0.11483281]]),
#  array([[0.01732267]]),
#  array([[0.]]),
#  array([[0.01740381]]),
#  array([[0.02711506]]),
#  array([[0.02098531]]),
#  array([[0.01164208]]),
#  array([[0.02531578]]),
#  array([[0.02162194]]),
#  array([[0.02091405]]),
#  array([[0.05092753]]),
#  array([[0.04012087]]),
#  array([[0.02923214]]),
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(df['All']) #fitting and transforming the vector
count_jobid
# Out:
# <20137x144460 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2913905 stored elements in Compressed Sparse Row format>

# %%
# print(count_jobid)

# %%
user_count = count_vectorizer.transform(df2['All'])
user_count
# Out:
# <1x144460 sparse matrix of type '<class 'numpy.int64'>'
# 	with 16 stored elements in Compressed Sparse Row format>

# %%
print(user_count)
# Out:
#   (0, 319)	1
#   (0, 341)	1
#   (0, 426)	3
#   (0, 465)	2
#   (0, 547)	2
#   (0, 726)	1
#   (0, 1620)	1
#   (0, 1630)	2
#   (0, 1641)	2
#   (0, 1659)	1
#   (0, 1713)	2
#   (0, 5024)	1
#   (0, 5219)	1
#   (0, 5262)	1
#   (0, 6712)	1
#   (0, 9721)	3
#   (0, 10005)	1
#   (0, 10006)	1
#   (0, 10107)	1
#   (0, 12424)	1
#   (0, 13076)	1
#   (0, 14287)	1
#   (0, 14310)	1
#   (0, 15754)	1
#   (0, 16326)	3
#   :	:
#   (0, 88743)	2
#   (0, 88882)	1
#   (0, 89694)	1
#   (0, 94758)	1
#   (0, 95328)	1
#   (0, 96077)	1
#   (0, 96687)	1
#   (0, 96745)	1
#   (0, 96754)	2
#   (0, 96773)	3
#   (0, 97411)	1
#   (0, 97538)	1
#   (0, 98163)	1
#   (0, 98230)	2
#   (0, 98806)	1
#   (0, 99413)	1
#   (0, 101197)	1
#   (0, 102115)	1
#   (0, 102946)	1
#   (0, 102954)	1
#   (0, 103660)	2
#   (0, 103733)	1
#   (0, 104226)	1
#   (0, 104810)	1
#   (0, 105680)	1

# %%
cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
output3 = list(cos_similarity_countv)
output3
# Out:
# [array([[0.10606602]]),
#  array([[0.07429292]]),
#  array([[0.10363524]]),
#  array([[0.09509652]]),
#  array([[0.14401646]]),
#  array([[0.08542422]]),
#  array([[0.07074606]]),
#  array([[0.06145682]]),
#  array([[0.17977193]]),
#  array([[0.06442805]]),
#  array([[0.05067726]]),
#  array([[0.08496707]]),
#  array([[0.06091078]]),
#  array([[0.06979961]]),
#  array([[0.10974773]]),
#  array([[0.09032199]]),
#  array([[0.13538808]]),
#  array([[0.05460401]]),
#  array([[0.07713446]]),
#  array([[0.10249591]]),
#  array([[0.0705801]]),
#  array([[0.08199201]]),
#  array([[0.10537566]]),
#  array([[0.08073902]]),
#  array([[0.10490611]]),
#  array([[0.06454972]]),
#  array([[0.14126158]]),
#  array([[0.07957672]]),
#  array([[0.12906237]]),
#  array([[0.07098422]]),
#  array([[0.15735293]]),
#  array([[0.10734582]]),
#  array([[0.07054481]]),
#  array([[0.08548248]]),
#  array([[0.08372498]]),
#  array([[0.05881197]]),
#  array([[0.07521405]]),
#  array([[0.09883773]]),
#  array([[0.09038769]]),
#  array([[0.11954652]]),
#  array([[0.16922964]]),
#  array([[0.07911685]]),
#  array([[0.11380532]]),
#  array([[0.08921723]]),
#  array([[0.08598154]]),
#  array([[0.12239838]]),
#  array([[0.11247482]]),
#  array([[0.15305349]]),
#  array([[0.13278188]]),
#  array([[0.13743685]]),
#  array([[0.06731891]]),
#  array([[0.10388221]]),
#  array([[0.150358]]),
#  array([[0.09178419]]),
#  array([[0.06821865]]),
#  array([[0.09165151]]),
#  array([[0.09178419]]),
#  array([[0.10826639]]),
#  array([[0.10617668]]),
#  array([[0.04033756]]),
#  array([[0.10431023]]),
#  array([[0.05766388]]),
#  array([[0.10878677]]),
#  array([[0.06839856]]),
#  array([[0.09240562]]),
#  array([[0.10232732]]),
#  array([[0.13139269]]),
#  array([[0.11338486]]),
#  array([[0.0962823]]),
#  array([[0.10439078]]),
#  array([[0.07764335]]),
#  array([[0.11752781]]),
#  array([[0.12976873]]),
#  array([[0.08833724]]),
#  array([[0.2006236]]),
#  array([[0.09262901]]),
#  array([[0.06005196]]),
#  array([[0.07216878]]),
#  array([[0.14046469]]),
#  array([[0.09622504]]),
#  array([[0.13197117]]),
#  array([[0.12044427]]),
#  array([[0.10163736]]),
#  array([[0.07261647]]),
#  array([[0.14658818]]),
#  array([[0.08958064]]),
#  array([[0.09328401]]),
#  array([[0.05999186]]),
#  array([[0.1575934]]),
#  array([[0.08357889]]),
#  array([[0.16702615]]),
#  array([[0.1385143]]),
#  array([[0.06216699]]),
#  array([[0.11128936]]),
#  array([[0.12528246]]),
#  array([[0.12939717]]),
#  array([[0.07504788]]),
#  array([[0.05870137]]),
#  array([[0.10590068]]),
#  array([[0.06406467]]),
#  array([[0.00560244]]),
#  array([[0.10073298]]),
#  array([[0.12757759]]),
#  array([[0.11712139]]),
#  array([[0.11226039]]),
#  array([[0.09225312]]),
#  array([[0.08480364]]),
#  array([[0.09471495]]),
#  array([[0.00533761]]),
#  array([[0.12174368]]),
#  array([[0.13986015]]),
#  array([[0.11030549]]),
#  array([[0.12563381]]),
#  array([[0.1118034]]),
#  array([[0.09119225]]),
#  array([[0.03841171]]),
#  array([[0.06320136]]),
#  array([[0.11270736]]),
#  array([[0.11185179]]),
#  array([[0.11477273]]),
#  array([[0.1015749]]),
#  array([[0.09426309]]),
#  array([[0.10089302]]),
#  array([[0.08262629]]),
#  array([[0.13100196]]),
#  array([[0.11343218]]),
#  array([[0.04567734]]),
#  array([[0.1142713]]),
#  array([[0.09668616]]),
#  array([[0.07637461]]),
#  array([[0.11168914]]),
#  array([[0.09393364]]),
#  array([[0.20017771]]),
#  array([[0.08783787]]),
#  array([[0.10179888]]),
#  array([[0.13766378]]),
#  array([[0.06785724]]),
#  array([[0.05780644]]),
#  array([[0.10257624]]),
#  array([[0.13272485]]),
#  array([[0.15039476]]),
#  array([[0.09711082]]),
#  array([[0.11005258]]),
#  array([[0.11072731]]),
#  array([[0.0741953]]),
#  array([[0.10875338]]),
#  array([[0.09039229]]),
#  array([[0.14874975]]),
#  array([[0.09804268]]),
#  array([[0.15361342]]),
#  array([[0.05951319]]),
#  array([[0.08866932]]),
#  array([[0.08963553]]),
#  array([[0.09409505]]),
#  array([[0.10960974]]),
#  array([[0.10167554]]),
#  array([[0.07949963]]),
#  array([[0.08713548]]),
#  array([[0.11077207]]),
#  array([[0.09935809]]),
#  array([[0.09272191]]),
#  array([[0.16208633]]),
#  array([[0.05345013]]),
#  array([[0.15113149]]),
#  array([[0.13355427]]),
#  array([[0.07902788]]),
#  array([[0.08189098]]),
#  array([[0.06556953]]),
#  array([[0.06944444]]),
#  array([[0.06202434]]),
#  array([[0.09294286]]),
#  array([[0.10119454]]),
#  array([[0.13675298]]),
#  array([[0.11033958]]),
#  array([[0.07182163]]),
#  array([[0.11394266]]),
#  array([[0.0483521]]),
#  array([[0.10793741]]),
#  array([[0.09821237]]),
#  array([[0.07184212]]),
#  array([[0.03605482]]),
#  array([[0.09148744]]),
#  array([[0.0490607]]),
#  array([[0.08583348]]),
#  array([[0.06016064]]),
#  array([[0.10160692]]),
#  array([[0.05792146]]),
#  array([[0.06962732]]),
#  array([[0.08333805]]),
#  array([[0.08468439]]),
#  array([[0.11501093]]),
#  array([[0.06363593]]),
#  array([[0.07173571]]),
#  array([[0.05772412]]),
#  array([[0.0595333]]),
#  array([[0.08056292]]),
#  array([[0.10858358]]),
#  array([[0.12065569]]),
#  array([[0.11638287]]),
#  array([[0.14580609]]),
#  array([[0.14323718]]),
#  array([[0.27355406]]),
#  array([[0.106217]]),
#  array([[0.08739505]]),
#  array([[0.06898092]]),
#  array([[0.14969549]]),
#  array([[0.20368085]]),
#  array([[0.07168692]]),
#  array([[0.13762009]]),
#  array([[0.05626924]]),
#  array([[0.080083]]),
#  array([[0.07088874]]),
#  array([[0.11260519]]),
#  array([[0.06859416]]),
#  array([[0.12855647]]),
#  array([[0.06021111]]),
#  array([[0.22970515]]),
#  array([[0.10272218]]),
#  array([[0.25451195]]),
#  array([[0.07828642]]),
#  array([[0.09025856]]),
#  array([[0.12472762]]),
#  array([[0.14459856]]),
#  array([[0.12264447]]),
#  array([[0.06379111]]),
#  array([[0.09831047]]),
#  array([[0.09393364]]),
#  array([[0.15433528]]),
#  array([[0.11522351]]),
#  array([[0.13056157]]),
#  array([[0.07612891]]),
#  array([[0.11462518]]),
#  array([[0.13091808]]),
#  array([[0.06246474]]),
#  array([[0.11552375]]),
#  array([[0.11024142]]),
#  array([[0.06762352]]),
#  array([[0.08575676]]),
#  array([[0.13127324]]),
#  array([[0.08540168]]),
#  array([[0.05416892]]),
#  array([[0.14128725]]),
#  array([[0.11575741]]),
#  array([[0.08410868]]),
#  array([[0.15128105]]),
#  array([[0.06775964]]),
#  array([[0.09346025]]),
#  array([[0.10888889]]),
#  array([[0.11618278]]),
#  array([[0.06480336]]),
#  array([[0.08110093]]),
#  array([[0.11633839]]),
#  array([[0.05432236]]),
#  array([[0.10453458]]),
#  array([[0.10167554]]),
#  array([[0.17085197]]),
#  array([[0.10067075]]),
#  array([[0.06469996]]),
#  array([[0.11509609]]),
#  array([[0.0958755]]),
#  array([[0.07029852]]),
#  array([[0.10878627]]),
#  array([[0.15772229]]),
#  array([[0.265747]]),
#  array([[0.12600066]]),
#  array([[0.11640898]]),
#  array([[0.09242227]]),
#  array([[0.09786903]]),
#  array([[0.10838804]]),
#  array([[0.09456109]]),
#  array([[0.06227284]]),
#  array([[0.14493033]]),
#  array([[0.0854046]]),
#  array([[0.31287684]]),
#  array([[0.08213423]]),
#  array([[0.16125539]]),
#  array([[0.14091482]]),
#  array([[0.05603155]]),
#  array([[0.03802156]]),
#  array([[0.04193112]]),
#  array([[0.15138252]]),
#  array([[0.07921456]]),
#  array([[0.08703883]]),
#  array([[0.00496904]]),
#  array([[0.09274778]]),
#  array([[0.35460407]]),
#  array([[0.15056344]]),
#  array([[0.10946797]]),
#  array([[0.10775563]]),
#  array([[0.08368274]]),
#  array([[0.12256789]]),
#  array([[0.1046604]]),
#  array([[0.16025747]]),
#  array([[0.10224482]]),
#  array([[0.16912733]]),
#  array([[0.11456439]]),
#  array([[0.1287779]]),
#  array([[0.05810642]]),
#  array([[0.37526689]]),
#  array([[0.1045631]]),
#  array([[0.11526851]]),
#  array([[0.11264701]]),
#  array([[0.09535036]]),
#  array([[0.1254468]]),
#  array([[0.05634362]]),
#  array([[0.09991687]]),
#  array([[0.10865728]]),
#  array([[0.16218471]]),
#  array([[0.06831395]]),
#  array([[0.11231703]]),
#  array([[0.03249376]]),
#  array([[0.08832083]]),
#  array([[0.13955445]]),
#  array([[0.06609542]]),
#  array([[0.10092168]]),
#  array([[0.12367391]]),
#  array([[0.05566438]]),
#  array([[0.10139588]]),
#  array([[0.11279389]]),
#  array([[0.05493999]]),
#  array([[0.06810657]]),
#  array([[0.053044]]),
#  array([[0.02868877]]),
#  array([[0.07612502]]),
#  array([[0.13524014]]),
#  array([[0.15823545]]),
#  array([[0.11088674]]),
#  array([[0.07031465]]),
#  array([[0.10248558]]),
#  array([[0.07147417]]),
#  array([[0.33333917]]),
#  array([[0.06012036]]),
#  array([[0.10866548]]),
#  array([[0.11907242]]),
#  array([[0.10152746]]),
#  array([[0.1030457]]),
#  array([[0.19025978]]),
#  array([[0.21053798]]),
#  array([[0.10235879]]),
#  array([[0.12909944]]),
#  array([[0.12990381]]),
#  array([[0.12455077]]),
#  array([[0.07976739]]),
#  array([[0.1028989]]),
#  array([[0.10566083]]),
#  array([[0.15665191]]),
#  array([[0.06836109]]),
#  array([[0.08888713]]),
#  array([[0.08642985]]),
#  array([[0.09875629]]),
#  array([[0.09023577]]),
#  array([[0.06606875]]),
#  array([[0.33366515]]),
#  array([[0.09119989]]),
#  array([[0.07661309]]),
#  array([[0.14275666]]),
#  array([[0.07444071]]),
#  array([[0.01968748]]),
#  array([[0.10453479]]),
#  array([[0.12272506]]),
#  array([[0.07423794]]),
#  array([[0.17821128]]),
#  array([[0.11515537]]),
#  array([[0.15365307]]),
#  array([[0.11593472]]),
#  array([[0.0597438]]),
#  array([[0.10681323]]),
#  array([[0.12759824]]),
#  array([[0.1141228]]),
#  array([[0.18081793]]),
#  array([[0.11353353]]),
#  array([[0.10753038]]),
#  array([[0.09155838]]),
#  array([[0.10094898]]),
#  array([[0.08427755]]),
#  array([[0.10725235]]),
#  array([[0.09906649]]),
#  array([[0.05767873]]),
#  array([[0.06446755]]),
#  array([[0.06744084]]),
#  array([[0.10172362]]),
#  array([[0.10486537]]),
#  array([[0.08193267]]),
#  array([[0.11603352]]),
#  array([[0.11011598]]),
#  array([[0.03938431]]),
#  array([[0.11623507]]),
#  array([[0.01434438]]),
#  array([[0.11019123]]),
#  array([[0.06678491]]),
#  array([[0.08369373]]),
#  array([[0.20445202]]),
#  array([[0.08054249]]),
#  array([[0.13675632]]),
#  array([[0.14552138]]),
#  array([[0.11028735]]),
#  array([[0.09970354]]),
#  array([[0.12912079]]),
#  array([[0.07989254]]),
#  array([[0.09085204]]),
#  array([[0.13053461]]),
#  array([[0.2213563]]),
#  array([[0.15770373]]),
#  array([[0.08239122]]),
#  array([[0.03685139]]),
#  array([[0.18703704]]),
#  array([[0.12719286]]),
#  array([[0.15266645]]),
#  array([[0.10757124]]),
#  array([[0.13736592]]),
#  array([[0.12939319]]),
#  array([[0.07157137]]),
#  array([[0.09640226]]),
#  array([[0.06266005]]),
#  array([[0.13471506]]),
#  array([[0.05098127]]),
#  array([[0.11118119]]),
#  array([[0.02997371]]),
#  array([[0.10795616]]),
#  array([[0.10550854]]),
#  array([[0.08012336]]),
#  array([[0.11231009]]),
#  array([[0.09711115]]),
#  array([[0.29529319]]),
#  array([[0.15254154]]),
#  array([[0.0703496]]),
#  array([[0.11226039]]),
#  array([[0.09229083]]),
#  array([[0.16103352]]),
#  array([[0.36682962]]),
#  array([[0.08311355]]),
#  array([[0.18328266]]),
#  array([[0.17917639]]),
#  array([[0.08022611]]),
#  array([[0.11837765]]),
#  array([[0.12649515]]),
#  array([[0.09001808]]),
#  array([[0.11839969]]),
#  array([[0.06824905]]),
#  array([[0.09587844]]),
#  array([[0.12933021]]),
#  array([[0.11277749]]),
#  array([[0.13866479]]),
#  array([[0.06956083]]),
#  array([[0.10740741]]),
#  array([[0.07282533]]),
#  array([[0.18779421]]),
#  array([[0.1328735]]),
#  array([[0.07995432]]),
#  array([[0.13567501]]),
#  array([[0.07708688]]),
#  array([[0.10151326]]),
#  array([[0.06168485]]),
#  array([[0.08593025]]),
#  array([[0.11534771]]),
#  array([[0.16521556]]),
#  array([[0.12113593]]),
#  array([[0.12527434]]),
#  array([[0.04485042]]),
#  array([[0.09908674]]),
#  array([[0.07784989]]),
#  array([[0.09127129]]),
#  array([[0.09689796]]),
#  array([[0.13724667]]),
#  array([[0.17344911]]),
#  array([[0.09879448]]),
#  array([[0.10962956]]),
#  array([[0.08924659]]),
#  array([[0.0675035]]),
#  array([[0.07784989]]),
#  array([[0.20852069]]),
#  array([[0.11846751]]),
#  array([[0.09109907]]),
#  array([[0.13990326]]),
#  array([[0.09097177]]),
#  array([[0.07815932]]),
#  array([[0.11631681]]),
#  array([[0.06548663]]),
#  array([[0.12734768]]),
#  array([[0.06255465]]),
#  array([[0.06247621]]),
#  array([[0.09719378]]),
#  array([[0.1495142]]),
#  array([[0.11526762]]),
#  array([[0.13205913]]),
#  array([[0.14627711]]),
#  array([[0.22253065]]),
#  array([[0.07186457]]),
#  array([[0.08834962]]),
#  array([[0.15200155]]),
#  array([[0.14663312]]),
#  array([[0.10856789]]),
#  array([[0.10764474]]),
#  array([[0.08015082]]),
#  array([[0.12267495]]),
#  array([[0.08291139]]),
#  array([[0.10193186]]),
#  array([[0.1035495]]),
#  array([[0.09008639]]),
#  array([[0.15996082]]),
#  array([[0.08021849]]),
#  array([[0.14120392]]),
#  array([[0.05370862]]),
#  array([[0.06974709]]),
#  array([[0.0840875]]),
#  array([[0.09688639]]),
#  array([[0.11503488]]),
#  array([[0.06979961]]),
#  array([[0.08214401]]),
#  array([[0.08881511]]),
#  array([[0.1194876]]),
#  array([[0.09954853]]),
#  array([[0.17782755]]),
#  array([[0.12125602]]),
#  array([[0.09672087]]),
#  array([[0.11345686]]),
#  array([[0.14076597]]),
#  array([[0.04948521]]),
#  array([[0.10200306]]),
#  array([[0.09637575]]),
#  array([[0.0908948]]),
#  array([[0.12970131]]),
#  array([[0.165636]]),
#  array([[0.08740074]]),
#  array([[0.18137809]]),
#  array([[0.09452181]]),
#  array([[0.12702147]]),
#  array([[0.07754558]]),
#  array([[0.07637399]]),
#  array([[0.09578523]]),
#  array([[0.06756902]]),
#  array([[0.05883527]]),
#  array([[0.11939043]]),
#  array([[0.08118136]]),
#  array([[0.11360751]]),
#  array([[0.11333333]]),
#  array([[0.15272366]]),
#  array([[0.12003739]]),
#  array([[0.09768088]]),
#  array([[0.13805543]]),
#  array([[0.15274298]]),
#  array([[0.05524315]]),
#  array([[0.08794275]]),
#  array([[0.10714492]]),
#  array([[0.11042874]]),
#  array([[0.11156231]]),
#  array([[0.21510758]]),
#  array([[0.08072909]]),
#  array([[0.10135978]]),
#  array([[0.14751734]]),
#  array([[0.06316338]]),
#  array([[0.09364246]]),
#  array([[0.12049138]]),
#  array([[0.10241272]]),
#  array([[0.05773503]]),
#  array([[0.10252482]]),
#  array([[0.13921151]]),
#  array([[0.1662308]]),
#  array([[0.09375253]]),
#  array([[0.07054681]]),
#  array([[0.04610694]]),
#  array([[0.11295427]]),
#  array([[0.12471856]]),
#  array([[0.11137997]]),
#  array([[0.07444071]]),
#  array([[0.15859942]]),
#  array([[0.12605487]]),
#  array([[0.07199758]]),
#  array([[0.10188393]]),
#  array([[0.1011008]]),
#  array([[0.14643944]]),
#  array([[0.1371641]]),
#  array([[0.12644286]]),
#  array([[0.08627375]]),
#  array([[0.03995528]]),
#  array([[0.12932338]]),
#  array([[0.16905017]]),
#  array([[0.1061415]]),
#  array([[0.11289148]]),
#  array([[0.08857691]]),
#  array([[0.09143836]]),
#  array([[0.14572987]]),
#  array([[0.10658388]]),
#  array([[0.19023448]]),
#  array([[0.12775075]]),
#  array([[0.08164966]]),
#  array([[0.1002748]]),
#  array([[0.14161178]]),
#  array([[0.11413955]]),
#  array([[0.07248161]]),
#  array([[0.09027715]]),
#  array([[0.10262821]]),
#  array([[0.10977059]]),
#  array([[0.07345741]]),
#  array([[0.10172362]]),
#  array([[0.04838206]]),
#  array([[0.07620735]]),
#  array([[0.07515674]]),
#  array([[0.12159627]]),
#  array([[0.03921116]]),
#  array([[0.38518208]]),
#  array([[0.1153164]]),
#  array([[0.08722829]]),
#  array([[0.10166376]]),
#  array([[0.09310068]]),
#  array([[0.07857711]]),
#  array([[0.07164552]]),
#  array([[0.1060964]]),
#  array([[0.06324233]]),
#  array([[0.14576357]]),
#  array([[0.04276995]]),
#  array([[0.0993808]]),
#  array([[0.07885027]]),
#  array([[0.10797898]]),
#  array([[0.18939207]]),
#  array([[0.15167004]]),
#  array([[0.11428693]]),
#  array([[0.08335303]]),
#  array([[0.13686834]]),
#  array([[0.0732645]]),
#  array([[0.14459557]]),
#  array([[0.10169436]]),
#  array([[0.10272175]]),
#  array([[0.10842456]]),
#  array([[0.11366572]]),
#  array([[0.10935925]]),
#  array([[0.12135761]]),
#  array([[0.09833041]]),
#  array([[0.05881428]]),
#  array([[0.10169504]]),
#  array([[0.22337829]]),
#  array([[0.12026712]]),
#  array([[0.08036435]]),
#  array([[0.05334349]]),
#  array([[0.06947399]]),
#  array([[0.06471848]]),
#  array([[0.15860425]]),
#  array([[0.11289419]]),
#  array([[0.0679254]]),
#  array([[0.13621313]]),
#  array([[0.06163156]]),
#  array([[0.38887252]]),
#  array([[0.]]),
#  array([[0.09404435]]),
#  array([[0.07056681]]),
#  array([[0.0904036]]),
#  array([[0.08644565]]),
#  array([[0.09495156]]),
#  array([[0.07120513]]),
#  array([[0.0404226]]),
#  array([[0.07724]]),
#  array([[0.08179585]]),
#  array([[0.05842893]]),
#  array([[0.10404562]]),
#  array([[0.07950999]]),
#  array([[0.38873865]]),
#  array([[0.12763039]]),
#  array([[0.09768925]]),
#  array([[0.09675207]]),
#  array([[0.13185913]]),
#  array([[0.10843866]]),
#  array([[0.07340143]]),
#  array([[0.13146433]]),
#  array([[0.15210878]]),
#  array([[0.09866]]),
#  array([[0.07566499]]),
#  array([[0.16410966]]),
#  array([[0.09617809]]),
#  array([[0.15423255]]),
#  array([[0.11451967]]),
#  array([[0.10647943]]),
#  array([[0.38415165]]),
#  array([[0.1156012]]),
#  array([[0.09548198]]),
#  array([[0.10704044]]),
#  array([[0.05245573]]),
#  array([[0.11940479]]),
#  array([[0.18688243]]),
#  array([[0.16311868]]),
#  array([[0.17139939]]),
#  array([[0.11343218]]),
#  array([[0.08910564]]),
#  array([[0.10719226]]),
#  array([[0.12524486]]),
#  array([[0.09522697]]),
#  array([[0.1059557]]),
#  array([[0.08323252]]),
#  array([[0.09460381]]),
#  array([[0.]]),
#  array([[0.09462978]]),
#  array([[0.05277063]]),
#  array([[0.10998534]]),
#  array([[0.00591106]]),
#  array([[0.09471576]]),
#  array([[0.150967]]),
#  array([[0.12508537]]),
#  array([[0.09309493]]),
#  array([[0.35222245]]),
#  array([[0.02260212]]),
#  array([[0.06123883]]),
#  array([[0.15515822]]),
#  array([[0.]]),
#  array([[0.0682854]]),
#  array([[0.11547005]]),
#  array([[0.10131759]]),
#  array([[0.08888889]]),
#  array([[0.08257303]]),
#  array([[0.07303201]]),
#  array([[0.06216699]]),
#  array([[0.08955473]]),
#  array([[0.13764944]]),
#  array([[0.13627164]]),
#  array([[0.09744941]]),
#  array([[0.16316356]]),
#  array([[0.06914388]]),
#  array([[0.16756273]]),
#  array([[0.13651003]]),
#  array([[0.17517543]]),
#  array([[0.0756874]]),
#  array([[0.15724184]]),
#  array([[0.0201466]]),
#  array([[0.10554663]]),
#  array([[0.13422372]]),
#  array([[0.09242227]]),
#  array([[0.08877061]]),
#  array([[0.08304913]]),
#  array([[0.06741734]]),
#  array([[0.07836039]]),
#  array([[0.08907453]]),
#  array([[0.07409844]]),
#  array([[0.07938052]]),
#  array([[0.10816215]]),
#  array([[0.14329103]]),
#  array([[0.1127469]]),
#  array([[0.15618154]]),
#  array([[0.08815728]]),
#  array([[0.08389861]]),
#  array([[0.08649988]]),
#  array([[0.09525793]]),
#  array([[0.07346706]]),
#  array([[0.0562633]]),
#  array([[0.19559281]]),
#  array([[0.10923386]]),
#  array([[0.11843131]]),
#  array([[0.05958796]]),
#  array([[0.10584755]]),
#  array([[0.11132876]]),
#  array([[0.08980351]]),
#  array([[0.10065731]]),
#  array([[0.17448808]]),
#  array([[0.07910741]]),
#  array([[0.09410679]]),
#  array([[0.14897812]]),
#  array([[0.05833333]]),
#  array([[0.07473046]]),
#  array([[0.07356124]]),
#  array([[0.14439329]]),
#  array([[0.05738476]]),
#  array([[0.12213225]]),
#  array([[0.07019264]]),
#  array([[0.06077395]]),
#  array([[0.11009043]]),
#  array([[0.04808905]]),
#  array([[0.0549348]]),
#  array([[0.14344383]]),
#  array([[0.18449002]]),
#  array([[0.30779733]]),
#  array([[0.14006097]]),
#  array([[0.06724339]]),
#  array([[0.10467747]]),
#  array([[0.09063233]]),
#  array([[0.08562747]]),
#  array([[0.13831378]]),
#  array([[0.09586736]]),
#  array([[0.13169649]]),
#  array([[0.06034688]]),
#  array([[0.08575676]]),
#  array([[0.07252393]]),
#  array([[0.25067359]]),
#  array([[0.14095976]]),
#  array([[0.07480933]]),
#  array([[0.13227764]]),
#  array([[0.18147857]]),
#  array([[0.08502794]]),
#  array([[0.10122303]]),
#  array([[0.13827129]]),
#  array([[0.35036181]]),
#  array([[0.10111849]]),
#  array([[0.07777778]]),
#  array([[0.09983841]]),
#  array([[0.05986843]]),
#  array([[0.09060112]]),
#  array([[0.12863348]]),
#  array([[0.32117203]]),
#  array([[0.16968049]]),
#  array([[0.09148744]]),
#  array([[0.1130886]]),
#  array([[0.1253201]]),
#  array([[0.07545553]]),
#  array([[0.06222222]]),
#  array([[0.07156601]]),
#  array([[0.102262]]),
#  array([[0.08041958]]),
#  array([[0.39937807]]),
#  array([[0.12990717]]),
#  array([[0.08480364]]),
#  array([[0.07374041]]),
#  array([[0.10275439]]),
#  array([[0.11623793]]),
#  array([[0.18611782]]),
#  array([[0.1123156]]),
#  array([[0.12566533]]),
#  array([[0.09949367]]),
#  array([[0.05415691]]),
#  array([[0.09535732]]),
#  array([[0.07190877]]),
#  array([[0.06247636]]),
#  array([[0.06896001]]),
#  array([[0.01160518]]),
#  array([[0.09063299]]),
#  array([[0.05709251]]),
#  array([[0.10378583]]),
#  array([[0.10944557]]),
#  array([[0.03742276]]),
#  array([[0.10634515]]),
#  array([[0.11939043]]),
#  array([[0.11851105]]),
#  array([[0.06634277]]),
#  array([[0.02621613]]),
#  array([[0.01740777]]),
#  array([[0.09855275]]),
#  array([[0.08713262]]),
#  array([[0.08973032]]),
#  array([[0.08316378]]),
#  array([[0.05895625]]),
#  array([[0.06274266]]),
#  array([[0.10423623]]),
#  array([[0.12109721]]),
#  array([[0.13451433]]),
#  array([[0.10663978]]),
#  array([[0.07438902]]),
#  array([[0.06929723]]),
#  array([[0.14713692]]),
#  array([[0.10952765]]),
#  array([[0.0746816]]),
#  array([[0.06838786]]),
#  array([[0.]]),
#  array([[0.03692745]]),
#  array([[0.09784134]]),
#  array([[0.10376311]]),
#  array([[0.1004662]]),
#  array([[0.09624355]]),
#  array([[0.09157015]]),
#  array([[0.10966454]]),
#  array([[0.07782896]]),
#  array([[0.15596681]]),
#  array([[0.10591333]]),
#  array([[0.43595941]]),
#  array([[0.01554175]]),
#  array([[0.101895]]),
#  array([[0.09548198]]),
#  array([[0.08926159]]),
#  array([[0.1407676]]),
#  array([[0.16948052]]),
#  array([[0.11014134]]),
#  array([[0.0766965]]),
#  array([[0.11204779]]),
#  array([[0.06059653]]),
#  array([[0.006415]]),
#  array([[0.12065896]]),
#  array([[0.19158319]]),
#  array([[0.07820384]]),
#  array([[0.10105823]]),
#  array([[0.13429817]]),
#  array([[0.08305902]]),
#  array([[0.08114408]]),
#  array([[0.06954616]]),
#  array([[0.10504583]]),
#  array([[0.08029903]]),
#  array([[0.25265353]]),
#  array([[0.08630916]]),
#  array([[0.09548198]]),
#  array([[0.05288119]]),
#  array([[0.16258694]]),
#  array([[0.24612544]]),
#  array([[0.33460193]]),
#  array([[0.09004503]]),
#  array([[0.10691149]]),
#  array([[0.18869285]]),
#  array([[0.18922254]]),
#  array([[0.01790287]]),
#  array([[0.05203149]]),
#  array([[0.10704512]]),
#  array([[0.08642616]]),
#  array([[0.14552138]]),
#  array([[0.11551225]]),
#  array([[0.1356451]]),
#  array([[0.13261001]]),
#  array([[0.1292769]]),
#  array([[0.04686383]]),
#  array([[0.08120672]]),
#  array([[0.27665708]]),
#  array([[0.11199021]]),
#  array([[0.06684874]]),
#  array([[0.10595356]]),
#  array([[0.12689023]]),
#  array([[0.18618987]]),
#  array([[0.11127523]]),
#  array([[0.13215221]]),
#  array([[0.12413221]]),
#  array([[0.08974653]]),
#  array([[0.10067614]]),
#  array([[0.03659625]]),
#  array([[0.0741504]]),
#  array([[0.10256046]]),
#  array([[0.12278289]]),
#  array([[0.12182492]]),
#  array([[0.1453283]]),
#  array([[0.12066025]]),
#  array([[0.13356461]]),
#  array([[0.06707807]]),
#  array([[0.09640226]]),
#  array([[0.08636665]]),
#  array([[0.13193347]]),
#  array([[0.12194489]]),
#  array([[0.0280056]]),
#  array([[0.08529547]]),
#  array([[0.09456671]]),
#  array([[0.13234294]]),
#  array([[0.10220635]]),
#  array([[0.14034124]]),
#  array([[0.08697708]]),
#  array([[0.1409527]]),
#  array([[0.10140162]]),
#  array([[0.06017124]]),
#  array([[0.14357392]]),
#  array([[0.30012052]]),
#  array([[0.12293749]]),
#  array([[0.1701799]]),
#  array([[0.05213017]]),
#  array([[0.11451124]]),
#  array([[0.14568243]]),
#  array([[0.07945393]]),
#  array([[0.14195574]]),
#  array([[0.15814002]]),
#  array([[0.08829267]]),
#  array([[0.08380019]]),
#  array([[0.1216018]]),
#  array([[0.2664004]]),
#  array([[0.24256475]]),
#  array([[0.06729341]]),
#  array([[0.07139727]]),
#  array([[0.07957672]]),
#  array([[0.29704999]]),
#  array([[0.11711716]]),
#  array([[0.07399854]]),
#  array([[0.08798781]]),
#  array([[0.05819144]]),
#  array([[0.05872202]]),
#  array([[0.10202256]]),
#  array([[0.16037507]]),
#  array([[0.06704483]]),
#  array([[0.19991775]]),
#  array([[0.09991746]]),
#  array([[0.05925553]]),
#  array([[0.09636176]]),
#  array([[0.10122204]]),
#  array([[0.10876421]]),
#  array([[0.10351753]]),
#  array([[0.07204282]]),
#  array([[0.10361165]]),
#  array([[0.12261032]]),
#  array([[0.05200187]]),
#  array([[0.09421683]]),
#  array([[0.08863822]]),
#  array([[0.35959211]]),
#  array([[0.09503181]]),
#  array([[0.11088319]]),
#  array([[0.10505254]]),
#  array([[0.08509282]]),
#  array([[0.07895108]]),
#  array([[0.23729292]]),
#  array([[0.17466059]]),
#  array([[0.0713074]]),
#  array([[0.07658357]]),
#  array([[0.11362982]]),
#  array([[0.05249995]]),
#  array([[0.17758882]]),
#  array([[0.06433252]]),
#  array([[0.03788857]]),
#  array([[0.08756844]]),
#  array([[0.09745089]]),
#  array([[0.07290668]]),
#  array([[0.06415677]]),
#  array([[0.08087495]]),
#  array([[0.09325048]]),
#  array([[0.05261522]]),
#  array([[0.10371833]]),
#  array([[0.07305801]]),
#  array([[0.0595338]]),
#  ...]

# %%
# output3 = count_vectorize(df['All'], df2['All'])
# output3

# %%
top = sorted(range(len(output3)), key=lambda i: output3[i], reverse=True)[:100]
list_scores = [output3[i][0][0] for i in top]
cv=get_recommendation(top, df, list_scores)
cv
# Out:
#    JobID                                              title  \
# 0   1402                              Senior Data Scientist
# 1   6868                                     Data Scientist
# 2   3942               Software Engineer Trainee (AI / GIS)
# 3   7259  Data Insights Analyst (Big Data- Machine Learn...
# 4   7582                           Data Scientist Team Lead
# ..   ...                                                ...
# 95  3997                                      Data Engineer
# 96  7347                   Manager, Data Quality Management
# 97  7567                     Data Architect / Data Engineer
# 98   936  3 headcounts (AM/ Manager/ Sr Manager) Data Go...
# 99  7474  Data Analyst/ Assistant Manager, Core Banking ...
#
#                                   industry  \
# 0                       Financial Services
# 1                       Financial Services
# 2                                   Others
# 3   Human Resources Management/Consultancy
# 4   Human Resources Management/Consultancy
# ..                                     ...
# 95                  Information Technology
# 96                      Financial Services
# 97                       Telecommunication
# 98  Human Resources Management/Consultancy
# 99                      Financial Services
#
#                                       job description     score
# 0   HASE Data OfficeThe Data Office of Hang Seng i...  0.449485
# 1   Your key responsibilitiesPerform data analysis...  0.421066
# 2   To participate in several large-scale Artifici...  0.420887
# 3   RESPONSIBILITIESPerform data analysis and prov...  0.420814
# 4   A top tier bank in Hk is hirirng for a data sc...  0.411256
# ..                                                ...       ...
# 95  Job ResponsibilitiesWork closely with business...  0.278737
# 96  Reporting to the Section Head - Data Quality M...  0.278429
# 97  OpportunitiesJoin us on an exciting venture to...  0.278214
# 98  Job Title:      AM/ Manager/ Sr Manager - Data...  0.277255
# 99  Reporting to the Project Manager / Head of Dat...  0.277005
#
# [100 rows x 5 columns]

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import NearestNeighbors

def KNN(scraped_data, cv):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')

    n_neighbors = 100
    KNN = NearestNeighbors(n_neighbors, p=2)
    KNN.fit(tfidf_vectorizer.fit_transform(scraped_data))
#     NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv), return_distance=True)
    NNs = KNN.kneighbors(tfidf_vectorizer.transform(cv))
    top = NNs[1][0][1:]
    index_score = NNs[0][0][1:]

    knn = get_recommendation(top, df, index_score)
    return knn

knn = KNN(df['All'], df2['All'])
knn
# Out:
# /Users/CooperLiPC/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:68: FutureWarning: Pass n_neighbors=100 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
#     JobID                                              title  \
# 0     641  Senior Machine Learning Engineer/Expert (Plann...
# 1    3942               Software Engineer Trainee (AI / GIS)
# 2   12794  Vice President, Big Data Analytics & Machine L...
# 3    7357  Associate Data Scientist/ Data Scientist - Top...
# 4    3247          Machine Learning Engineer/ Data Scientist
# ..    ...                                                ...
# 94  14851             SENIOR ESTATE MANAGER / ESTATE MANAGER
# 95   7276  Chief Data Architect - MNC, Digital Transforma...
# 96   7374                                     Data Scientist
# 97   3109     Director - Artificial Intelligence (AI) & Data
# 98   2546  (Senior) Data Engineer | Multiple Openings | P...
#
#                                   industry  \
# 0                   Information Technology
# 1                                   Others
# 2                       Financial Services
# 3   Human Resources Management/Consultancy
# 4                        Telecommunication
# ..                                     ...
# 94       Property Management / Consultancy
# 95  Human Resources Management/Consultancy
# 96                  Information Technology
# 97  Human Resources Management/Consultancy
# 98  Human Resources Management/Consultancy
#
#                                       job description    score
# 0   Job Responsibilities:•Responsible for the algo...  1.19014
# 1   To participate in several large-scale Artifici...  1.19847
# 2   Responsibilities:Explore the availability, acc...  1.22004
# 3   Junior Data Scientist focused on machine learn...   1.2204
# 4   Machine Learning Engineer/ Data ScientistOppor...  1.23118
# ..                                                ...      ...
# 94  Responsibilities Overall monitoring a team of ...  1.32229
# 95  About the ClientOur client is well established...  1.32229
# 96  Job Responsibilities:Develop and implement Mac...  1.32285
# 97  Our Client:Our client is a conglomerate group ...  1.32362
# 98  Data Engineer | FSI | Perm | 40 - 48kDuties:Re...  1.32549
#
# [99 rows x 5 columns]

# %%
knn.to_csv('knn.csv', index=False)

# %% [markdown]
# # Combined TFIDF, CV and KNN result together, to make a dataframe "final"

# %%
# merge1 = knn[['JobID','title', 'score']].merge(TF[['JobID','score']], on= "JobID")
# final = merge1.merge(cv[['JobID','score']], on = "JobID")
# final = final.rename(columns={"score_x": "KNN", "score_y": "TF-IDF","score": "CV"})
# final.head()

merge1 = knn[['JobID','title', 'score']].merge(TF[['JobID','score']], on= "JobID")
final = merge1.merge(cv[['JobID','score']], on = "JobID")
final = final.rename(columns={"score_x": "KNN", "score_y": "TF-IDF","score": "CV"})
final.head()
# Out:
#    JobID                                              title      KNN  \
# 0    641  Senior Machine Learning Engineer/Expert (Plann...  1.19014
# 1   3942               Software Engineer Trainee (AI / GIS)  1.19847
# 2  12794  Vice President, Big Data Analytics & Machine L...  1.22004
# 3   7357  Associate Data Scientist/ Data Scientist - Top...   1.2204
# 4   3247          Machine Learning Engineer/ Data Scientist  1.23118
#
#      TF-IDF        CV
# 0  0.291789  0.364723
# 1  0.281831  0.420887
# 2  0.255755  0.360825
# 3  0.255316  0.403841
# 4  0.242092  0.410141

# %%
# high = max(knn['score'])
# def reverseScoring(df, high, cols):
#     '''Reverse scores on given columns
#      df = your data frame,
#      high = highest score available
#      cols = the columns you want reversed in list form'''
#     df[cols] = high - df[cols]
# #     return df['score']
#     return df
# reverseScoring(knn, high, 'score')

# %%
# reverseScoring(knn, high, 'score').to_csv('test.csv', index=False)

# %% [markdown]
# # Scale and assign weights

# %%
# Scale it
from sklearn.preprocessing import MinMaxScaler
slr = MinMaxScaler()
final[["KNN", "TF-IDF", 'CV']] = slr.fit_transform(final[["KNN", "TF-IDF", 'CV']])

# Multiply by weights
final['KNN'] = (1-final['KNN'])/3
final['TF-IDF'] = final['TF-IDF']/3
final['CV'] = final['CV']/3
final['Final'] = final['KNN']+final['TF-IDF']+final['CV']
final.sort_values(by="Final", ascending=False)
# Out:
#    JobID                                              title         KNN  \
# 0    641  Senior Machine Learning Engineer/Expert (Plann...    0.333333
# 3   7357  Associate Data Scientist/ Data Scientist - Top...     0.27341
# 7   7259  Data Insights Analyst (Big Data- Machine Learn...    0.249845
# 2   3942               Software Engineer Trainee (AI / GIS)    0.275054
# 10   857                           Associate Data Scientist    0.214888
# ..   ...                                                ...         ...
# 52   885       Programmer, Machine Learning/ AI development   0.0270944
# 48  1844               Software / Machine Learning Engineer   0.0403543
# 59  7603         Data Scientist - Leading Bank in Hong Kong  0.00491511
# 56  5566  Senior Consultant / Manager, Data Scientist, D...   0.0194597
# 60  1157           Data Scientist / Computational Scientist           0
#
#         TF-IDF           CV       Final
# 0     0.333333     0.189947    0.856614
# 3     0.275167     0.278731    0.827308
# 7     0.252081     0.325352    0.827278
# 2     0.276773     0.248643     0.80047
# 10    0.217617     0.310602    0.743106
# ..         ...          ...         ...
# 52    0.027984    0.0508848    0.105963
# 48   0.0416218   0.00386648   0.0858426
# 59  0.00508816    0.0321145   0.0421177
# 56   0.0201146  0.000522725    0.040097
# 60           0   0.00414767  0.00414767
#
# [61 rows x 6 columns]

# %%
# final.to_csv('final.csv', index=False)
final2 = final.sort_values(by="Final", ascending=False).copy()
final2
# Out:
#    JobID                                              title         KNN  \
# 0    641  Senior Machine Learning Engineer/Expert (Plann...    0.333333
# 3   7357  Associate Data Scientist/ Data Scientist - Top...     0.27341
# 7   7259  Data Insights Analyst (Big Data- Machine Learn...    0.249845
# 2   3942               Software Engineer Trainee (AI / GIS)    0.275054
# 10   857                           Associate Data Scientist    0.214888
# ..   ...                                                ...         ...
# 52   885       Programmer, Machine Learning/ AI development   0.0270944
# 48  1844               Software / Machine Learning Engineer   0.0403543
# 59  7603         Data Scientist - Leading Bank in Hong Kong  0.00491511
# 56  5566  Senior Consultant / Manager, Data Scientist, D...   0.0194597
# 60  1157           Data Scientist / Computational Scientist           0
#
#         TF-IDF           CV       Final
# 0     0.333333     0.189947    0.856614
# 3     0.275167     0.278731    0.827308
# 7     0.252081     0.325352    0.827278
# 2     0.276773     0.248643     0.80047
# 10    0.217617     0.310602    0.743106
# ..         ...          ...         ...
# 52    0.027984    0.0508848    0.105963
# 48   0.0416218   0.00386648   0.0858426
# 59  0.00508816    0.0321145   0.0421177
# 56   0.0201146  0.000522725    0.040097
# 60           0   0.00414767  0.00414767
#
# [61 rows x 6 columns]

# %%
final2.head(10)
# Out:
#     JobID                                              title       KNN  \
# 0     641  Senior Machine Learning Engineer/Expert (Plann...  0.333333
# 3    7357  Associate Data Scientist/ Data Scientist - Top...   0.27341
# 7    7259  Data Insights Analyst (Big Data- Machine Learn...  0.249845
# 2    3942               Software Engineer Trainee (AI / GIS)  0.275054
# 10    857                           Associate Data Scientist  0.214888
# 8    7312          Artificial Intelligence (AI) R&D Engineer  0.242279
# 9    5717  Data Science Manager - Machine Learning/AI | 2...  0.239048
# 4   12794  Vice President, Big Data Analytics & Machine L...  0.270547
# 12   3247          Machine Learning Engineer/ Data Scientist   0.19946
# 14   7582                           Data Scientist Team Lead  0.178896
#
#       TF-IDF        CV     Final
# 0   0.333333  0.189947  0.856614
# 3   0.275167  0.278731  0.827308
# 7   0.252081  0.325352  0.827278
# 2   0.276773  0.248643   0.80047
# 10  0.217617  0.310602  0.743106
# 8   0.244644  0.238304  0.725226
# 9   0.241464  0.212282  0.692794
# 4   0.272368  0.142904  0.685819
# 12  0.202323  0.259108   0.66089
# 14  0.181858  0.299642  0.660395

# %%
# final2.merge(df, on="JobID")
final_salary = df.merge(final2, on="JobID")
final_salary
# Out:
#     Unnamed: 0  JobID                                            title_x  \
# 0          285    285                      Data Analyst (System Analyst)
# 1          298    298                                     Data Scientist
# 2          352    352                                       Data Analyst
# 3          429    429  Data Science Intern (6-9 months contract from ...
# 4          641    641  Senior Machine Learning Engineer/Expert (Plann...
# ..         ...    ...                                                ...
# 56        7582   7582                           Data Scientist Team Lead
# 57        7603   7603         Data Scientist - Leading Bank in Hong Kong
# 58       10911  10911  Manager and Strategic Lead, Learning Analytics...
# 59       12794  12794  Vice President, Big Data Analytics & Machine L...
# 60       13897  13897  CIB Global Research - Applied AI & Machine Lea...
#
#                                               company            location  \
# 0     China Life Insurance (Overseas) Company Limited            Hung Hom
# 1                                                Arup        Kowloon City
# 2   China State Construction Engineering (Hong Kon...            Wan Chai
# 3                                       AXA Hong Kong       Southern Area
# 4     TCL Corporate Research (Hong Kong) Co., Limited         Shatin Area
# ..                                                ...                 ...
# 56                        Cornerstone Global Partners  Yau Tsim Mong Area
# 57                                       Michael Page                 NaN
# 58                                 Lingnan University       Tuen Mun Area
# 59  China Construction Bank (Asia) Corporation Lim...                 NaN
# 60                          JPMorgan Chase Bank, N.A.                 NaN
#
#    salary            post_date  \
# 0       0   Posted 4 hours ago
# 1       0  Posted on 14-Jul-21
# 2       0  Posted on 13-Jul-21
# 3       0  Posted on 14-Jul-21
# 4       0  Posted 21 hours ago
# ..    ...                  ...
# 56      0  Posted on 17-Jun-21
# 57      0  Posted on 16-Jun-21
# 58      0  Posted on 23-Jun-21
# 59      0  Posted on 13-Jul-21
# 60      0   Posted on 8-Jul-21
#
#                                        job highlights  \
# 0   SQL, Python, Tableau/Congo’s, Machine Learning...
# 1   Degree in Mathematics, Data Science or related...
# 2   Degree holder with 3 year's big data analysis ...
# 3   Exposure to Life Insurance Data Science, Full-...
# 4   reinforcement learning, Postdoc, deep learning...
# ..                                                ...
# 56                 team lead, data scientist, finance
# 57  Permanent Headcount, New Data Initiatives, Pre...
# 58  work across the University to leverage data, l...
# 59        Data Management, Big Data, Machine Learning
# 60  Minimum 6 years experience in a data analytics...
#
#                                       job description  \
# 0   Responsibilities:Perform data architecture, da...
# 1   Responsibilities:Create, develop and maintain ...
# 2   Job Description:Develop reference modules and ...
# 3   Career OpportunitiesLearn to solve real busine...
# 4   Job Responsibilities:•Responsible for the algo...
# ..                                                ...
# 56  A top tier bank in Hk is hirirng for a data sc...
# 57  The Data Scientist will sit in the centralised...
# 58  Lingnan University, a distinctive liberal arts...
# 59  Responsibilities:Explore the availability, acc...
# 60  Data Analytics at JPMorgan Corporate Investmen...
#
#                                      company overview  ...  \
# 0   China Life Insurance (Overseas) Company Limite...  ...
# 1   Arup is the creative force at the heart of man...  ...
# 2   We are a listed group with diversified interes...  ...
# 3   ABOUT AXA HONG KONG\n\nAXA Hong Kong, a member...  ...
# 4   TCL is one of the world’s leading manufacturer...  ...
# ..                                                ...  ...
# 56                                      top tier bank  ...
# 57  As part of PageGroup, Michael Page is a leadin...  ...
# 58                                                NaN  ...
# 59  China Construction Bank (Asia) Corporation Lim...  ...
# 60  J.P. Morgan is a global leader in financial se...  ...
#
#                                               benefit  \
# 0   Education allowance, Life insurance, Medical i...
# 1   Double pay, Life insurance, Medical insurance,...
# 2                                                 NaN
# 3                                                 NaN
# 4   Dental insurance, Medical insurance, Performan...
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59  Dental insurance, Life insurance, Medical insu...
# 60                                                NaN
#
#                                               webpage sal_low sal_high  \
# 0   https://hk.jobsdb.com/hk/en/job/data-analyst-s...       0        0
# 1   https://hk.jobsdb.com/hk/en/job/data-scientist...       0        0
# 2   https://hk.jobsdb.com/hk/en/job/data-analyst-1...       0        0
# 3   https://hk.jobsdb.com/hk/en/job/data-science-i...       0        0
# 4   https://hk.jobsdb.com/hk/en/job/senior-machine...       0        0
# ..                                                ...     ...      ...
# 56  https://hk.jobsdb.com/hk/en/job/data-scientist...       0        0
# 57  https://hk.jobsdb.com/hk/en/job/data-scientist...       0        0
# 58  https://hk.jobsdb.com/hk/en/job/manager-and-st...       0        0
# 59  https://hk.jobsdb.com/hk/en/job/vice-president...       0        0
# 60  https://hk.jobsdb.com/hk/en/job/cib-global-res...       0        0
#
#                                                   All  \
# 0   ['data analyst system analyst china life insur...
# 1   ['data scientist arup degree mathematics data ...
# 2   ["data analyst china state construction engine...
# 3   ['data science intern 6-9 month contract aug/s...
# 4   ['senior machine learning engineer/expert plan...
# ..                                                ...
# 56  ['data scientist team lead cornerstone global ...
# 57  ["data scientist leading bank michael permanen...
# 58  ['manager strategic lead learning analytics po...
# 59  ["vice president big data analytics machine le...
# 60  ["cib global applied ai machine learning lead ...
#
#                                               title_y         KNN      TF-IDF  \
# 0                       Data Analyst (System Analyst)   0.0236292   0.0244137
# 1                                      Data Scientist   0.0773623   0.0794853
# 2                                        Data Analyst   0.0602258   0.0619891
# 3   Data Science Intern (6-9 months contract from ...   0.0537436   0.0553546
# 4   Senior Machine Learning Engineer/Expert (Plann...    0.333333    0.333333
# ..                                                ...         ...         ...
# 56                           Data Scientist Team Lead    0.178896    0.181858
# 57         Data Scientist - Leading Bank in Hong Kong  0.00491511  0.00508816
# 58  Manager and Strategic Lead, Learning Analytics...    0.133919    0.136782
# 59  Vice President, Big Data Analytics & Machine L...    0.270547    0.272368
# 60  CIB Global Research - Applied AI & Machine Lea...    0.254214     0.25637
#
#            CV      Final
# 0    0.102138   0.150181
# 1    0.155084   0.311932
# 2   0.0484844   0.170699
# 3    0.133465   0.242563
# 4    0.189947   0.856614
# ..        ...        ...
# 56   0.299642   0.660395
# 57  0.0321145  0.0421177
# 58  0.0429749   0.313676
# 59   0.142904   0.685819
# 60  0.0918602   0.602444
#
# [61 rows x 25 columns]
